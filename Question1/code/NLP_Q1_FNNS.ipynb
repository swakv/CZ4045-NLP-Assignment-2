# %%
# Q1_data
import os
from io import open
import torch

# Q1_model
import math
import torch.nn as nn
import torch.nn.functional as F

#Q1_main
# import argparse
import time
import torch.onnx
import numpy as np
from torch.autograd import Variable
import multiprocessing

# %% [code]
class Dictionary(object):
    def __init__(self):
        self.word2idx = {}
        self.idx2word = []

    def add_word(self, word):
        if word not in self.word2idx:
            self.idx2word.append(word)
            self.word2idx[word] = len(self.idx2word) - 1
        return self.word2idx[word]

    def __len__(self):
        return len(self.idx2word)


class Corpus(object):
    def __init__(self):
        self.dictionary = Dictionary()
        self.train = self.tokenize('../input/nlpdata/wikitext-2/wiki.train.tokens')
        self.valid = self.tokenize('../input/nlpdata/wikitext-2/wiki.valid.tokens')
        self.test = self.tokenize( '../input/nlpdata/wikitext-2/wiki.test.tokens')

    def tokenize(self, path):
        """Tokenizes a text file."""
       
        assert os.path.exists(path)
        # Add words to the dictionary
        with open(path, 'r', encoding="utf8") as f:
            for line in f:
                words = line.split() + ['<eos>']
                for word in words:
                    self.dictionary.add_word(word)

        # Tokenize file content
        with open(path, 'r', encoding="utf8") as f:
            idss = []
            for line in f:
                words = line.split() + ['<eos>']
                ids = []
                for word in words:
                    ids.append(self.dictionary.word2idx[word])
                idss.append(torch.tensor(ids).type(torch.int64))
            # print("idss",len(idss))
            ids = torch.cat(idss)
            # print("ids",len(ids))

        return ids


class RNNModel(nn.Module):
    """Container module with an encoder, a recurrent module, and a decoder."""

    def __init__(self, rnn_type, ntoken, ninp, nhid, nlayers, dropout=0.5, tie_weights=False):
        super(RNNModel, self).__init__()
        self.ntoken = ntoken # VOCAB SIZE
        self.drop = nn.Dropout(dropout)
        self.encoder = nn.Embedding(ntoken, ninp)
        if rnn_type in ['LSTM', 'GRU']:
            self.rnn = getattr(nn, rnn_type)(ninp, nhid, nlayers, dropout=dropout)
            # print(rnn_type)
        else:
            try:
                nonlinearity = {'RNN_TANH': 'tanh', 'RNN_RELU': 'relu'}[rnn_type]
            except KeyError:
                raise ValueError( """An invalid option for `--model` was supplied,
                                 options are ['LSTM', 'GRU', 'RNN_TANH' or 'RNN_RELU']""")
            self.rnn = nn.RNN(ninp, nhid, nlayers, nonlinearity=nonlinearity, dropout=dropout) # input size, hidden dimension, no of hidden layers size
        self.decoder = nn.Linear(nhid, ntoken) # hidden dimension, vocab size

        # Optionally tie weights as in:
        # "Using the Output Embedding to Improve Language Models" (Press & Wolf 2016)
        # https://arxiv.org/abs/1608.05859
        # and
        # "Tying Word Vectors and Word Classifiers: A Loss Framework for Language Modeling" (Inan et al. 2016)
        # https://arxiv.org/abs/1611.01462
        if tie_weights:
            if nhid != ninp:
                raise ValueError('When using the tied flag, nhid must be equal to emsize')
            self.decoder.weight = self.encoder.weight

        self.init_weights()

        self.rnn_type = rnn_type
        self.nhid = nhid
        self.nlayers = nlayers

    def init_weights(self):
        initrange = 0.1
        nn.init.uniform_(self.encoder.weight, -initrange, initrange)
        nn.init.zeros_(self.decoder.weight)
        nn.init.uniform_(self.decoder.weight, -initrange, initrange)

    def forward(self, input, hidden):
        emb = self.drop(self.encoder(input))
        output, hidden = self.rnn(emb, hidden)
        output = self.drop(output)
        decoded = self.decoder(output)
        decoded = decoded.view(-1, self.ntoken)
        return F.log_softmax(decoded, dim=1), hidden

    def init_hidden(self, bsz):
        weight = next(self.parameters())
        if self.rnn_type == 'LSTM':
            return (weight.new_zeros(self.nlayers, bsz, self.nhid),
                    weight.new_zeros(self.nlayers, bsz, self.nhid))
        else:
            return weight.new_zeros(self.nlayers, bsz, self.nhid)

# Temporarily leave PositionalEncoding module here. Will be moved somewhere else.
class PositionalEncoding(nn.Module):
    r"""Inject some information about the relative or absolute position of the tokens
        in the sequence. The positional encodings have the same dimension as
        the embeddings, so that the two can be summed. Here, we use sine and cosine
        functions of different frequencies.
    .. math::
        \text{PosEncoder}(pos, 2i) = sin(pos/10000^(2i/d_model))
        \text{PosEncoder}(pos, 2i+1) = cos(pos/10000^(2i/d_model))
        \text{where pos is the word position and i is the embed idx)
    Args:
        d_model: the embed dim (required).
        dropout: the dropout value (default=0.1).
        max_len: the max. length of the incoming sequence (default=5000).
    Examples:
        >>> pos_encoder = PositionalEncoding(d_model)
    """

    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        r"""Inputs of forward function
        Args:
            x: the sequence fed to the positional encoder model (required).
        Shape:
            x: [sequence length, batch size, embed dim]
            output: [sequence length, batch size, embed dim]
        Examples:
            >>> output = pos_encoder(x)
        """

        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

class TransformerModel(nn.Module):
    """Container module with an encoder, a recurrent or transformer module, and a decoder."""

    def _init_(self, ntoken, ninp, nhead, nhid, nlayers, dropout=0.5):
        super(TransformerModel, self)._init_()
        try:
            from torch.nn import TransformerEncoder, TransformerEncoderLayer
        except:
            raise ImportError('TransformerEncoder module does not exist in PyTorch 1.1 or lower.')
        self.model_type = 'Transformer'
        self.src_mask = None
        self.pos_encoder = PositionalEncoding(ninp, dropout)
        encoder_layers = TransformerEncoderLayer(ninp, nhead, nhid, dropout)
        self.transformer_encoder = TransformerEncoder(encoder_layers, nlayers)
        self.encoder = nn.Embedding(ntoken, ninp)
        self.ninp = ninp
        self.decoder = nn.Linear(ninp, ntoken)

        self.init_weights()

    def _generate_square_subsequent_mask(self, sz):
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask

    def init_weights(self):
        initrange = 0.1
        nn.init.uniform_(self.encoder.weight, -initrange, initrange)
        nn.init.zeros_(self.decoder.weight)
        nn.init.uniform_(self.decoder.weight, -initrange, initrange)

    def forward(self, src, has_mask=True):
        if has_mask:
            device = src.device
            if self.src_mask is None or self.src_mask.size(0) != len(src):
                mask = self._generate_square_subsequent_mask(len(src)).to(device)
                self.src_mask = mask
        else:
            self.src_mask = None

        src = self.encoder(src) * math.sqrt(self.ninp)
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src, self.src_mask)
        output = self.decoder(output)
        return F.log_softmax(output, dim=-1)



class FNNModel(nn.Module):

    def __init__(self, ntoken, ninp, nhid):
        super(FNNModel, self).__init__()

        self.embeddings = nn.Embedding(ntoken, ninp)
       
        self.linear = nn.Linear(7*ninp, nhid)
        self.linear2 = nn.Linear(nhid, ntoken)

        self.ntoken = ntoken
        self.init_weights()
        self.nhid = nhid

    def init_weights(self):
        initrange = 0.1
        nn.init.uniform_(self.embeddings.weight, -initrange, initrange)
        nn.init.zeros_(self.linear2.weight)
        nn.init.uniform_(self.linear2.weight, -initrange, initrange)

    def forward(self, input):
        embeds = self.embeddings(input)
        embeds = embeds.view(1,-1)
        out = F.tanh(self.linear(embeds))
        log_probs = F.log_softmax(self.linear2(out))
        return log_probs

class FNNModelSharing(nn.Module):

    def __init__(self, ntoken, ninp, nhid):
        super(FNNModelSharing, self).__init__()

        self.embeddings = nn.Embedding(ntoken, ninp)
       
        self.linear = nn.Linear(7*ninp, nhid)
        self.linear2 = nn.Linear(nhid, ntoken)
       
        self.linear2.weight.data = self.embeddings.weight.data

        self.ntoken = ntoken
        self.init_weights()
        self.nhid = nhid

    def init_weights(self):
        initrange = 0.1
        nn.init.uniform_(self.embeddings.weight, -initrange, initrange)
        nn.init.zeros_(self.linear2.weight)
        nn.init.uniform_(self.linear2.weight, -initrange, initrange)

    def forward(self, input):
        embeds = self.embeddings(input)
        embeds = embeds.view(1,-1)
        out = F.tanh(self.linear(embeds))
       
        out = self.linear2(out)
        log_probs = F.log_softmax(out, dim=1)
        return log_probs


data = 'wikitext-2'
model_name = 'FNNS'
emsize = 200
nhid = 200
nlayers = 2
lr = 0.0003
clip = 0.25
epochs = 6
batch_size = 20
bptt = 8
dropout = 0.2
seed = 1111
tied = True
save = 'model_kag.pt'
onnx_export = ''
nhead = 2
dry_run = False
cuda_var = True
log_interval = 100

# Set the random seed manually for reproducibility.
torch.manual_seed(seed)
if torch.cuda.is_available():
    if not cuda_var:
        print("WARNING: You have a CUDA device, so you should probably run with --cuda")

device = torch.device("cuda" if cuda_var else "cpu")

###############################################################################
# Load data
###############################################################################

corpus = Corpus()
# print("final train",len(corpus.train))

# Starting from sequential data, batchify arranges the dataset into columns.
# For instance, with the alphabet as the sequence and batch size 4, we'd get
# ┌ a g m s ┐
# │ b h n t │
# │ c i o u │
# │ d j p v │
# │ e k q w │
# └ f l r x ┘.
# These columns are treated as independent by the model, which means that the
# dependence of e. g. 'g' on 'f' can not be learned, but allows more efficient
# batch processing.

def batchify(data, bsz):
    # Work out how cleanly we can divide the dataset into bsz parts.
    nbatch = data.size(0) // bsz
    # Trim off any extra elements that wouldn't cleanly fit (remainders).
    data = data.narrow(0, 0, nbatch * bsz)
    # Evenly divide the data across the bsz batches.
    data = data.view(bsz, -1).t().contiguous()
    print("data type ------ ", data.shape)
    return data.to(device)

# torch.Size([104431, 20])
ngram_here = torch.split(corpus.train, 7)
ngram_here = [t.numpy() for t in ngram_here]
ngram_here = ngram_here[:-1]
ngram_here = torch.tensor(ngram_here)
ngram_here = ngram_here.to(device)

val_data = torch.split(corpus.valid, 7)
val_data = [t.numpy() for t in val_data]
val_data = val_data[:-1]
val_data = torch.tensor(val_data)
val_data = val_data.to(device)

test_data = torch.split(corpus.test, 7)
test_data = [t.numpy() for t in test_data]
test_data = test_data[:-1]
test_data = torch.tensor(test_data)
test_data = test_data.to(device)
print("reached")

eval_batch_size = 10
if model_name  != 'FNN' and model_name != 'FNNS':
    train_data = batchify(corpus.train, batch_size)
    val_data = batchify(corpus.valid, eval_batch_size)
    test_data = batchify(corpus.test, eval_batch_size)
   


###############################################################################
# Build the model
###############################################################################

ntokens = len(corpus.dictionary)
if model_name  == 'Transformer':
    model = TransformerModel(ntokens, emsize, nhead, nhid, nlayers, dropout).to(device)
elif  model_name  == 'FNN':
    model = FNNModel(ntokens, emsize, nhid)
    optimizer = torch.optim.Adam(model.parameters(), lr = lr)
elif model_name  == 'FNNS':
    model = FNNModelSharing(ntokens, emsize, nhid)
    optimizer = torch.optim.Adam(model.parameters(), lr = lr)
    # optimizer = torch.optim.SGD(model.parameters(), lr, momentum=0.9)
else:
    model = RNNModel(model_name, ntokens, emsize, nhid, nlayers, dropout, tied).to(device)
 

criterion = nn.NLLLoss()

###############################################################################
# Training code
###############################################################################

def repackage_hidden(h):
    """Wraps hidden states in new Tensors, to detach them from their history."""

    if isinstance(h, torch.Tensor):
        return h.detach()
    else:
        return tuple(repackage_hidden(v) for v in h)


# get_batch subdivides the source data into chunks of length bptt.
# If source is equal to the example output of the batchify function, with
# a bptt-limit of 2, we'd get the following two Variables for i = 0:
# ┌ a g m s ┐ ┌ b h n t ┐
# └ b h n t ┘ └ c i o u ┘
# Note that despite the name of the function, the subdivison of data is not
# done along the batch dimension (i.e. dimension 1), since that was handled
# by the batchify function. The chunks are along dimension 0, corresponding
# to the seq_len dimension in the LSTM.

def get_batch(source, i):
    # print("i " ,i)
    seq_len = min(bptt, len(source) - 1 - i)
    # print("SEQLEN",seq_len)
    data = source[i:i+seq_len]
    # print("DATA SHAPE ",data.shape)
    target = source[i+1:i+1+seq_len].view(-1)
    return data, target


def evaluate(data_source):
    # Turn on evaluation mode which disables dropout.
    model.eval()
    total_loss = 0.
    ntokens = len(corpus.dictionary)
    if model_name  != 'Transformer' and model_name  != 'FNN' and model_name  != 'FNNS':
        hidden = model.init_hidden(eval_batch_size)
   
    with torch.no_grad():
        if model_name  != 'FNN' and model_name  != 'FNNS':
            for i in range(0, data_source.size(0) - 1, bptt):
                data, targets = get_batch(data_source, i)
                if model_name  == 'Transformer' or model_name  == 'FNN' or model_name  == 'FNNS':
                    output = model(data)
                    output = output.view(-1, ntokens)
                else:
                    output, hidden = model(data, hidden)
                    hidden = repackage_hidden(hidden)
                print("len of data", len(data))
                total_loss += len(data) * criterion(output, targets).item()
        else: #for FNN
            for i in range(len(data_source)-1):
                data = data_source[i]
                ngram_copy = list(data_source[i+1])
                targets = ngram_copy[0]
                targets = [targets]
                targets = torch.tensor(targets)
                targets = targets.to(device)
                #print("tar",targets)
                output = model(data)
                #print("op", output)
#                 print("critereonnnn",criterion(output, targets).item())
                total_loss +=  criterion(output, targets).item()
                
#                 if i % log_interval == 0 and i > 0:
#                     total_loss = 0
#     print("data source -- ",len(data_source))
    return total_loss / (len(data_source) - 1)



def train():
    # Turn on training mode which enables dropout.
    model.train()
    total_loss = 0.
    start_time = time.time()
    ntokens = len(corpus.dictionary)
    # print("--------", model)
    if model_name  != 'Transformer' and model_name  != 'FNN' and model_name  != 'FNNS':
        hidden = model.init_hidden(batch_size)
    if model_name  != 'FNN' and model_name  != 'FNNS':
        for batch, i in enumerate(range(0, int(train_data.size(0)/10000) - 1, bptt)):
            # print("batch issssss",batch)
            data, targets = get_batch(train_data, i)
#             print("data-------",data)
            print("target-----", targets)
            # Starting each batch, we detach the hidden state from how it was previously produced.
            # If we didn't, the model would try backpropagating all the way to start of the dataset.
            model.zero_grad()
            if model_name  == 'Transformer' or model_name  == 'FNN' or model_name == 'FNNS':
                optimizer.zero_grad()
                output = model(data)
                output = output.view(-1, ntokens)
                
            else:
                hidden = repackage_hidden(hidden)
                output, hidden = model(data, hidden)
                print("output---", output)
            loss = criterion(output, targets)
            loss.backward()
            # optimizer.step()


            # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
            # if model != 'Transformer' and model != 'FNN':
            torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
            for p in model.parameters():
                p.data.add_(p.grad, alpha=-lr)

            total_loss += loss.item()

            if batch % log_interval == 0 and batch > 0:
                cur_loss = total_loss / log_interval
                elapsed = time.time() - start_time
                print('| epoch {:3d} | {:5d}/{:5d} batches | lr {:02.4f} | ms/batch {:5.2f} | '
                        'loss {:5.2f} | ppl {:8.2f}'.format(
                    epoch, batch, len(train_data) // bptt, lr,
                    elapsed * 1000 / log_interval,
                    cur_loss,
                    np.exp(cur_loss)))
                total_loss = 0
                start_time = time.time()
            if dry_run:
                break
               
    else: #for FNN
        # print("here")
        count = 0
        for i in range(int(len(ngram_here))-1):
            data = ngram_here[i]
            ngram_copy = list(ngram_here[i+1])
            targets = ngram_copy[0]
            targets = [targets]
            targets = torch.tensor(targets)
            targets = targets.to(device)
            # print("data", data)
            # print("target", targets)
           
            model.zero_grad()
            model.to(device)
            optimizer.zero_grad()
            output = model(data)
            # print("op", output)
            loss = criterion(output, targets)
            loss.backward()
            optimizer.step()

            torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
            for p in model.parameters():
                p.data.add_(p.grad, alpha=-lr)

            total_loss += loss.item()

            if count % log_interval == 0 and count > 0:
                cur_loss = total_loss / log_interval
                elapsed = time.time() - start_time
                print('| epoch {:3d} | seq number {:3d} | lr {:02.4f} | '
                        'loss {:5.2f} | ppl {:8.2f}'.format(
                    epoch, count, lr,
                    cur_loss,
                    np.exp(cur_loss)))
                total_loss = 0
                start_time = time.time()

            count+=1



def export_onnx(path, batch_size, seq_len):
    print('The model is also exported in ONNX format at {}'.
          format(os.path.realpath(onnx_export)))
    model.eval()
    dummy_input = torch.LongTensor(seq_len * batch_size).zero_().view(-1, batch_size).to(device)
   
    hidden = model.init_hidden(batch_size)
    torch.onnx.export(model, (dummy_input, hidden), path)
    
    

# Loop over epochs.
lr = lr
best_val_loss = None

# At any point you can hit Ctrl + C to break out of training early.
try:
    for epoch in range(1, epochs+1):
        epoch_start_time = time.time()
        train()
        val_loss = evaluate(val_data)
        print('-' * 89)
        print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
                'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                           val_loss, np.exp(val_loss))) #math
        print('-' * 89)
        
        # Save the model if the validation loss is the best we've seen so far.
        if not best_val_loss or val_loss < best_val_loss:
            with open(save, 'wb') as f:
                torch.save(model, f)
            best_val_loss = val_loss
        else:
            # Anneal the learning rate if no improvement has been seen in the validation dataset.
            lr /= 4.0
except KeyboardInterrupt:
    print('-' * 89)
    print('Exiting from training early')

# Load the best saved model.
with open(save, 'rb') as f:
    model = torch.load(f)
    # after load the rnn params are not a continuous chunk of memory
    # Currently, only rnn model supports flatten_parameters function.
    if model_name  in ['RNN_TANH', 'RNN_RELU', 'LSTM', 'GRU']:
        model.rnn.flatten_parameters()

# Run on test data.
test_loss = evaluate(test_data)
print('=' * 89)
print('| End of training | test loss {:5.2f} | test ppl {:8.2f}'.format(
    test_loss, math.exp(test_loss)))
print('=' * 89)

if len(onnx_export) > 0:
    # Export the model in ONNX format.
    export_onnx(onnx_export, batch_size=1, seq_len=bptt)
# Out:
# reached
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1614: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# | epoch   1 | seq number 100 | lr 0.0003 | loss 10.51 | ppl 36542.45
# | epoch   1 | seq number 200 | lr 0.0003 | loss 10.36 | ppl 31511.88
# | epoch   1 | seq number 300 | lr 0.0003 | loss 10.20 | ppl 26905.61
# | epoch   1 | seq number 400 | lr 0.0003 | loss  9.89 | ppl 19716.10
# | epoch   1 | seq number 500 | lr 0.0003 | loss  8.28 | ppl  3955.72
# | epoch   1 | seq number 600 | lr 0.0003 | loss  8.17 | ppl  3544.42
# | epoch   1 | seq number 700 | lr 0.0003 | loss  8.50 | ppl  4897.13
# | epoch   1 | seq number 800 | lr 0.0003 | loss  7.71 | ppl  2229.50
# | epoch   1 | seq number 900 | lr 0.0003 | loss  8.06 | ppl  3163.07
# | epoch   1 | seq number 1000 | lr 0.0003 | loss  8.37 | ppl  4309.50
# | epoch   1 | seq number 1100 | lr 0.0003 | loss  7.93 | ppl  2790.34
# | epoch   1 | seq number 1200 | lr 0.0003 | loss  7.89 | ppl  2683.03
# | epoch   1 | seq number 1300 | lr 0.0003 | loss  7.23 | ppl  1384.87
# | epoch   1 | seq number 1400 | lr 0.0003 | loss  8.42 | ppl  4528.70
# | epoch   1 | seq number 1500 | lr 0.0003 | loss  8.35 | ppl  4228.82
# | epoch   1 | seq number 1600 | lr 0.0003 | loss  8.37 | ppl  4303.87
# | epoch   1 | seq number 1700 | lr 0.0003 | loss  8.10 | ppl  3306.88
# | epoch   1 | seq number 1800 | lr 0.0003 | loss  7.75 | ppl  2329.22
# | epoch   1 | seq number 1900 | lr 0.0003 | loss  8.33 | ppl  4126.37
# | epoch   1 | seq number 2000 | lr 0.0003 | loss  7.52 | ppl  1840.09
# | epoch   1 | seq number 2100 | lr 0.0003 | loss  7.79 | ppl  2416.14
# | epoch   1 | seq number 2200 | lr 0.0003 | loss  8.57 | ppl  5276.16
# | epoch   1 | seq number 2300 | lr 0.0003 | loss  8.62 | ppl  5515.14
# | epoch   1 | seq number 2400 | lr 0.0003 | loss  7.63 | ppl  2069.28
# | epoch   1 | seq number 2500 | lr 0.0003 | loss  7.71 | ppl  2224.95
# | epoch   1 | seq number 2600 | lr 0.0003 | loss  7.73 | ppl  2282.60
# | epoch   1 | seq number 2700 | lr 0.0003 | loss  7.11 | ppl  1220.81
# | epoch   1 | seq number 2800 | lr 0.0003 | loss  7.28 | ppl  1447.22
# | epoch   1 | seq number 2900 | lr 0.0003 | loss  7.61 | ppl  2016.71
# | epoch   1 | seq number 3000 | lr 0.0003 | loss  7.73 | ppl  2275.21
# | epoch   1 | seq number 3100 | lr 0.0003 | loss  8.02 | ppl  3030.05
# | epoch   1 | seq number 3200 | lr 0.0003 | loss  8.27 | ppl  3892.81
# | epoch   1 | seq number 3300 | lr 0.0003 | loss  8.67 | ppl  5821.92
# | epoch   1 | seq number 3400 | lr 0.0003 | loss  8.05 | ppl  3130.66
# | epoch   1 | seq number 3500 | lr 0.0003 | loss  7.90 | ppl  2709.86
# | epoch   1 | seq number 3600 | lr 0.0003 | loss  7.52 | ppl  1847.30
# | epoch   1 | seq number 3700 | lr 0.0003 | loss  7.75 | ppl  2327.75
# | epoch   1 | seq number 3800 | lr 0.0003 | loss  7.77 | ppl  2377.02
# | epoch   1 | seq number 3900 | lr 0.0003 | loss  7.39 | ppl  1612.70
# | epoch   1 | seq number 4000 | lr 0.0003 | loss  8.16 | ppl  3485.90
# | epoch   1 | seq number 4100 | lr 0.0003 | loss  7.81 | ppl  2464.76
# | epoch   1 | seq number 4200 | lr 0.0003 | loss  8.19 | ppl  3601.63
# | epoch   1 | seq number 4300 | lr 0.0003 | loss  7.93 | ppl  2770.16
# | epoch   1 | seq number 4400 | lr 0.0003 | loss  7.71 | ppl  2225.66
# | epoch   1 | seq number 4500 | lr 0.0003 | loss  8.24 | ppl  3774.13
# | epoch   1 | seq number 4600 | lr 0.0003 | loss  8.07 | ppl  3205.48
# | epoch   1 | seq number 4700 | lr 0.0003 | loss  8.29 | ppl  3974.89
# | epoch   1 | seq number 4800 | lr 0.0003 | loss  8.21 | ppl  3690.33
# | epoch   1 | seq number 4900 | lr 0.0003 | loss  7.99 | ppl  2942.26
# | epoch   1 | seq number 5000 | lr 0.0003 | loss  8.18 | ppl  3568.64
# | epoch   1 | seq number 5100 | lr 0.0003 | loss  7.83 | ppl  2507.20
# | epoch   1 | seq number 5200 | lr 0.0003 | loss  7.83 | ppl  2519.79
# | epoch   1 | seq number 5300 | lr 0.0003 | loss  7.69 | ppl  2190.41
# | epoch   1 | seq number 5400 | lr 0.0003 | loss  7.15 | ppl  1267.88
# | epoch   1 | seq number 5500 | lr 0.0003 | loss  7.18 | ppl  1309.86
# | epoch   1 | seq number 5600 | lr 0.0003 | loss  7.17 | ppl  1294.15
# | epoch   1 | seq number 5700 | lr 0.0003 | loss  7.19 | ppl  1324.23
# | epoch   1 | seq number 5800 | lr 0.0003 | loss  7.86 | ppl  2604.19
# | epoch   1 | seq number 5900 | lr 0.0003 | loss  8.20 | ppl  3642.60
# | epoch   1 | seq number 6000 | lr 0.0003 | loss  8.16 | ppl  3499.39
# | epoch   1 | seq number 6100 | lr 0.0003 | loss  7.64 | ppl  2080.00
# | epoch   1 | seq number 6200 | lr 0.0003 | loss  8.60 | ppl  5442.07
# | epoch   1 | seq number 6300 | lr 0.0003 | loss  7.76 | ppl  2348.53
# | epoch   1 | seq number 6400 | lr 0.0003 | loss  8.34 | ppl  4177.16
# | epoch   1 | seq number 6500 | lr 0.0003 | loss  7.99 | ppl  2964.40
# | epoch   1 | seq number 6600 | lr 0.0003 | loss  7.93 | ppl  2771.14
# | epoch   1 | seq number 6700 | lr 0.0003 | loss  8.19 | ppl  3587.71
# | epoch   1 | seq number 6800 | lr 0.0003 | loss  7.13 | ppl  1247.72
# | epoch   1 | seq number 6900 | lr 0.0003 | loss  7.77 | ppl  2378.63
# | epoch   1 | seq number 7000 | lr 0.0003 | loss  7.49 | ppl  1789.66
# | epoch   1 | seq number 7100 | lr 0.0003 | loss  8.25 | ppl  3826.06
# | epoch   1 | seq number 7200 | lr 0.0003 | loss  7.83 | ppl  2513.02
# | epoch   1 | seq number 7300 | lr 0.0003 | loss  6.96 | ppl  1052.14
# | epoch   1 | seq number 7400 | lr 0.0003 | loss  8.56 | ppl  5230.76
# | epoch   1 | seq number 7500 | lr 0.0003 | loss  7.85 | ppl  2557.44
# | epoch   1 | seq number 7600 | lr 0.0003 | loss  7.71 | ppl  2219.87
# | epoch   1 | seq number 7700 | lr 0.0003 | loss  7.38 | ppl  1602.68
# | epoch   1 | seq number 7800 | lr 0.0003 | loss  7.50 | ppl  1809.36
# | epoch   1 | seq number 7900 | lr 0.0003 | loss  8.12 | ppl  3357.04
# | epoch   1 | seq number 8000 | lr 0.0003 | loss  7.82 | ppl  2493.42
# | epoch   1 | seq number 8100 | lr 0.0003 | loss  7.52 | ppl  1848.27
# | epoch   1 | seq number 8200 | lr 0.0003 | loss  7.89 | ppl  2669.30
# | epoch   1 | seq number 8300 | lr 0.0003 | loss  7.43 | ppl  1693.05
# | epoch   1 | seq number 8400 | lr 0.0003 | loss  7.39 | ppl  1619.32
# | epoch   1 | seq number 8500 | lr 0.0003 | loss  6.96 | ppl  1053.05
# | epoch   1 | seq number 8600 | lr 0.0003 | loss  7.53 | ppl  1869.23
# | epoch   1 | seq number 8700 | lr 0.0003 | loss  7.01 | ppl  1110.60
# | epoch   1 | seq number 8800 | lr 0.0003 | loss  7.50 | ppl  1800.56
# | epoch   1 | seq number 8900 | lr 0.0003 | loss  7.69 | ppl  2178.16
# | epoch   1 | seq number 9000 | lr 0.0003 | loss  7.12 | ppl  1239.39
# | epoch   1 | seq number 9100 | lr 0.0003 | loss  8.14 | ppl  3441.69
# | epoch   1 | seq number 9200 | lr 0.0003 | loss  8.32 | ppl  4085.32
# | epoch   1 | seq number 9300 | lr 0.0003 | loss  7.78 | ppl  2398.43
# | epoch   1 | seq number 9400 | lr 0.0003 | loss  7.87 | ppl  2609.76
# | epoch   1 | seq number 9500 | lr 0.0003 | loss  7.52 | ppl  1838.84
# | epoch   1 | seq number 9600 | lr 0.0003 | loss  7.34 | ppl  1546.23
# | epoch   1 | seq number 9700 | lr 0.0003 | loss  7.54 | ppl  1886.61
# | epoch   1 | seq number 9800 | lr 0.0003 | loss  7.95 | ppl  2845.20
# | epoch   1 | seq number 9900 | lr 0.0003 | loss  7.62 | ppl  2032.69
# | epoch   1 | seq number 10000 | lr 0.0003 | loss  8.72 | ppl  6118.49
# | epoch   1 | seq number 10100 | lr 0.0003 | loss  7.43 | ppl  1682.55
# | epoch   1 | seq number 10200 | lr 0.0003 | loss  8.26 | ppl  3858.85
# | epoch   1 | seq number 10300 | lr 0.0003 | loss  7.65 | ppl  2106.29
# | epoch   1 | seq number 10400 | lr 0.0003 | loss  7.93 | ppl  2777.97
# | epoch   1 | seq number 10500 | lr 0.0003 | loss  7.89 | ppl  2683.60
# | epoch   1 | seq number 10600 | lr 0.0003 | loss  8.10 | ppl  3292.05
# | epoch   1 | seq number 10700 | lr 0.0003 | loss  7.12 | ppl  1239.06
# | epoch   1 | seq number 10800 | lr 0.0003 | loss  8.32 | ppl  4107.50
# | epoch   1 | seq number 10900 | lr 0.0003 | loss  8.11 | ppl  3313.74
# | epoch   1 | seq number 11000 | lr 0.0003 | loss  8.23 | ppl  3749.57
# | epoch   1 | seq number 11100 | lr 0.0003 | loss  6.97 | ppl  1065.49
# | epoch   1 | seq number 11200 | lr 0.0003 | loss  7.56 | ppl  1928.71
# | epoch   1 | seq number 11300 | lr 0.0003 | loss  7.60 | ppl  1996.15
# | epoch   1 | seq number 11400 | lr 0.0003 | loss  7.10 | ppl  1207.96
# | epoch   1 | seq number 11500 | lr 0.0003 | loss  6.57 | ppl   714.19
# | epoch   1 | seq number 11600 | lr 0.0003 | loss  7.24 | ppl  1390.02
# | epoch   1 | seq number 11700 | lr 0.0003 | loss  6.55 | ppl   700.69
# | epoch   1 | seq number 11800 | lr 0.0003 | loss  7.25 | ppl  1402.65
# | epoch   1 | seq number 11900 | lr 0.0003 | loss  6.99 | ppl  1087.31
# | epoch   1 | seq number 12000 | lr 0.0003 | loss  7.20 | ppl  1344.71
# | epoch   1 | seq number 12100 | lr 0.0003 | loss  6.80 | ppl   900.47
# | epoch   1 | seq number 12200 | lr 0.0003 | loss  7.26 | ppl  1424.25
# | epoch   1 | seq number 12300 | lr 0.0003 | loss  6.94 | ppl  1031.75
# | epoch   1 | seq number 12400 | lr 0.0003 | loss  7.96 | ppl  2868.96
# | epoch   1 | seq number 12500 | lr 0.0003 | loss  7.37 | ppl  1580.57
# | epoch   1 | seq number 12600 | lr 0.0003 | loss  8.33 | ppl  4128.51
# | epoch   1 | seq number 12700 | lr 0.0003 | loss  7.74 | ppl  2294.19
# | epoch   1 | seq number 12800 | lr 0.0003 | loss  6.48 | ppl   654.74
# | epoch   1 | seq number 12900 | lr 0.0003 | loss  8.31 | ppl  4067.40
# | epoch   1 | seq number 13000 | lr 0.0003 | loss  8.22 | ppl  3701.10
# | epoch   1 | seq number 13100 | lr 0.0003 | loss  6.59 | ppl   728.80
# | epoch   1 | seq number 13200 | lr 0.0003 | loss  8.06 | ppl  3175.73
# | epoch   1 | seq number 13300 | lr 0.0003 | loss  7.18 | ppl  1310.40
# | epoch   1 | seq number 13400 | lr 0.0003 | loss  8.01 | ppl  3007.82
# | epoch   1 | seq number 13500 | lr 0.0003 | loss  8.27 | ppl  3923.04
# | epoch   1 | seq number 13600 | lr 0.0003 | loss  8.55 | ppl  5145.19
# | epoch   1 | seq number 13700 | lr 0.0003 | loss  6.75 | ppl   850.38
# | epoch   1 | seq number 13800 | lr 0.0003 | loss  6.45 | ppl   631.78
# | epoch   1 | seq number 13900 | lr 0.0003 | loss  7.58 | ppl  1950.34
# | epoch   1 | seq number 14000 | lr 0.0003 | loss  6.85 | ppl   941.85
# | epoch   1 | seq number 14100 | lr 0.0003 | loss  7.61 | ppl  2016.15
# | epoch   1 | seq number 14200 | lr 0.0003 | loss  7.21 | ppl  1350.17
# | epoch   1 | seq number 14300 | lr 0.0003 | loss  7.76 | ppl  2350.47
# | epoch   1 | seq number 14400 | lr 0.0003 | loss  6.63 | ppl   760.40
# | epoch   1 | seq number 14500 | lr 0.0003 | loss  7.64 | ppl  2072.08
# | epoch   1 | seq number 14600 | lr 0.0003 | loss  7.66 | ppl  2113.30
# | epoch   1 | seq number 14700 | lr 0.0003 | loss  7.41 | ppl  1657.91
# | epoch   1 | seq number 14800 | lr 0.0003 | loss  7.13 | ppl  1246.85
# | epoch   1 | seq number 14900 | lr 0.0003 | loss  7.10 | ppl  1209.63
# | epoch   1 | seq number 15000 | lr 0.0003 | loss  7.51 | ppl  1823.02
# | epoch   1 | seq number 15100 | lr 0.0003 | loss  7.65 | ppl  2093.40
# | epoch   1 | seq number 15200 | lr 0.0003 | loss  7.37 | ppl  1591.82
# | epoch   1 | seq number 15300 | lr 0.0003 | loss  7.10 | ppl  1216.78
# | epoch   1 | seq number 15400 | lr 0.0003 | loss  7.79 | ppl  2414.78
# | epoch   1 | seq number 15500 | lr 0.0003 | loss  6.75 | ppl   851.36
# | epoch   1 | seq number 15600 | lr 0.0003 | loss  6.82 | ppl   919.05
# | epoch   1 | seq number 15700 | lr 0.0003 | loss  8.65 | ppl  5722.58
# | epoch   1 | seq number 15800 | lr 0.0003 | loss  7.77 | ppl  2377.13
# | epoch   1 | seq number 15900 | lr 0.0003 | loss  8.06 | ppl  3160.70
# | epoch   1 | seq number 16000 | lr 0.0003 | loss  7.71 | ppl  2228.31
# | epoch   1 | seq number 16100 | lr 0.0003 | loss  7.32 | ppl  1510.51
# | epoch   1 | seq number 16200 | lr 0.0003 | loss  7.73 | ppl  2265.02
# | epoch   1 | seq number 16300 | lr 0.0003 | loss  7.14 | ppl  1259.38
# | epoch   1 | seq number 16400 | lr 0.0003 | loss  7.91 | ppl  2737.38
# | epoch   1 | seq number 16500 | lr 0.0003 | loss  8.06 | ppl  3166.83
# | epoch   1 | seq number 16600 | lr 0.0003 | loss  6.53 | ppl   684.14
# | epoch   1 | seq number 38500 | lr 0.0003 | loss  7.05 | ppl  1153.90
# | epoch   1 | seq number 38600 | lr 0.0003 | loss  6.98 | ppl  1072.32
# | epoch   1 | seq number 38700 | lr 0.0003 | loss  7.31 | ppl  1498.28
# | epoch   1 | seq number 38800 | lr 0.0003 | loss  7.09 | ppl  1204.25
# | epoch   1 | seq number 38900 | lr 0.0003 | loss  7.48 | ppl  1771.21
# | epoch   1 | seq number 39000 | lr 0.0003 | loss  7.09 | ppl  1196.20
# | epoch   1 | seq number 39100 | lr 0.0003 | loss  6.51 | ppl   675.11
# | epoch   1 | seq number 39200 | lr 0.0003 | loss  7.11 | ppl  1219.92
# | epoch   1 | seq number 39300 | lr 0.0003 | loss  6.83 | ppl   921.75
# | epoch   1 | seq number 39400 | lr 0.0003 | loss  7.43 | ppl  1686.96
# | epoch   1 | seq number 39500 | lr 0.0003 | loss  6.99 | ppl  1088.13
# | epoch   1 | seq number 39600 | lr 0.0003 | loss  6.85 | ppl   944.40
# | epoch   1 | seq number 39700 | lr 0.0003 | loss  7.11 | ppl  1228.68
# | epoch   1 | seq number 39800 | lr 0.0003 | loss  6.73 | ppl   841.21
# | epoch   1 | seq number 39900 | lr 0.0003 | loss  8.07 | ppl  3183.06
# | epoch   1 | seq number 40000 | lr 0.0003 | loss  7.42 | ppl  1670.51
# | epoch   1 | seq number 40100 | lr 0.0003 | loss  7.19 | ppl  1327.35
# | epoch   1 | seq number 40200 | lr 0.0003 | loss  7.69 | ppl  2186.56
# | epoch   1 | seq number 40300 | lr 0.0003 | loss  7.50 | ppl  1803.16
# | epoch   1 | seq number 40400 | lr 0.0003 | loss  7.44 | ppl  1699.65
# | epoch   1 | seq number 40500 | lr 0.0003 | loss  7.04 | ppl  1146.28
# | epoch   1 | seq number 40600 | lr 0.0003 | loss  7.35 | ppl  1561.22
# | epoch   1 | seq number 40700 | lr 0.0003 | loss  6.88 | ppl   976.79
# | epoch   1 | seq number 40800 | lr 0.0003 | loss  7.15 | ppl  1279.84
# | epoch   1 | seq number 40900 | lr 0.0003 | loss  7.07 | ppl  1172.85
# | epoch   1 | seq number 41000 | lr 0.0003 | loss  7.30 | ppl  1475.63
# | epoch   1 | seq number 41100 | lr 0.0003 | loss  6.94 | ppl  1034.94
# | epoch   1 | seq number 41200 | lr 0.0003 | loss  8.34 | ppl  4195.51
# | epoch   1 | seq number 41300 | lr 0.0003 | loss  7.22 | ppl  1366.13
# | epoch   1 | seq number 41400 | lr 0.0003 | loss  7.03 | ppl  1132.84
# | epoch   1 | seq number 41500 | lr 0.0003 | loss  7.63 | ppl  2055.36
# | epoch   1 | seq number 41600 | lr 0.0003 | loss  7.50 | ppl  1802.82
# | epoch   1 | seq number 41700 | lr 0.0003 | loss  7.26 | ppl  1425.88
# | epoch   1 | seq number 41800 | lr 0.0003 | loss  8.01 | ppl  3024.23
# | epoch   1 | seq number 41900 | lr 0.0003 | loss  6.88 | ppl   975.58
# | epoch   1 | seq number 42000 | lr 0.0003 | loss  7.74 | ppl  2287.19
# | epoch   1 | seq number 63800 | lr 0.0003 | loss  7.72 | ppl  2253.31
# | epoch   1 | seq number 63900 | lr 0.0003 | loss  6.68 | ppl   797.68
# | epoch   1 | seq number 64000 | lr 0.0003 | loss  7.27 | ppl  1440.33
# | epoch   1 | seq number 64100 | lr 0.0003 | loss  7.67 | ppl  2148.55
# | epoch   1 | seq number 64200 | lr 0.0003 | loss  7.55 | ppl  1904.45
# | epoch   1 | seq number 64300 | lr 0.0003 | loss  7.95 | ppl  2843.97
# | epoch   1 | seq number 64400 | lr 0.0003 | loss  8.41 | ppl  4509.66
# | epoch   1 | seq number 64500 | lr 0.0003 | loss  7.06 | ppl  1163.10
# | epoch   1 | seq number 64600 | lr 0.0003 | loss  7.65 | ppl  2099.71
# | epoch   1 | seq number 64700 | lr 0.0003 | loss  7.58 | ppl  1953.72
# | epoch   1 | seq number 64800 | lr 0.0003 | loss  7.67 | ppl  2143.84
# | epoch   1 | seq number 64900 | lr 0.0003 | loss  8.20 | ppl  3623.16
# | epoch   1 | seq number 65000 | lr 0.0003 | loss  8.14 | ppl  3438.74
# | epoch   1 | seq number 65100 | lr 0.0003 | loss  7.69 | ppl  2188.43
# | epoch   1 | seq number 65200 | lr 0.0003 | loss  8.26 | ppl  3848.39
# | epoch   1 | seq number 65300 | lr 0.0003 | loss  8.66 | ppl  5792.91
# | epoch   1 | seq number 65400 | lr 0.0003 | loss  8.00 | ppl  2995.22
# | epoch   1 | seq number 65500 | lr 0.0003 | loss  7.86 | ppl  2587.80
# | epoch   1 | seq number 65600 | lr 0.0003 | loss  8.05 | ppl  3140.14
# | epoch   1 | seq number 65700 | lr 0.0003 | loss  6.70 | ppl   813.48
# | epoch   1 | seq number 65800 | lr 0.0003 | loss  7.29 | ppl  1461.53
# | epoch   1 | seq number 65900 | lr 0.0003 | loss  7.31 | ppl  1492.09
# | epoch   1 | seq number 66000 | lr 0.0003 | loss  6.91 | ppl  1007.01
# | epoch   1 | seq number 66100 | lr 0.0003 | loss  7.15 | ppl  1269.24
# | epoch   1 | seq number 66200 | lr 0.0003 | loss  8.25 | ppl  3818.70
# | epoch   1 | seq number 66300 | lr 0.0003 | loss  7.11 | ppl  1224.96
# | epoch   1 | seq number 66400 | lr 0.0003 | loss  8.35 | ppl  4249.26
# | epoch   1 | seq number 66500 | lr 0.0003 | loss  8.08 | ppl  3233.03
# | epoch   1 | seq number 66600 | lr 0.0003 | loss  7.83 | ppl  2507.55
# | epoch   1 | seq number 66700 | lr 0.0003 | loss  7.43 | ppl  1686.92
# | epoch   1 | seq number 66800 | lr 0.0003 | loss  7.79 | ppl  2408.11
# | epoch   1 | seq number 66900 | lr 0.0003 | loss  8.89 | ppl  7230.65
# | epoch   1 | seq number 67000 | lr 0.0003 | loss  8.05 | ppl  3131.48
# | epoch   1 | seq number 67100 | lr 0.0003 | loss  8.11 | ppl  3330.27
# | epoch   1 | seq number 67200 | lr 0.0003 | loss  6.89 | ppl   984.68
# | epoch   1 | seq number 67300 | lr 0.0003 | loss  7.44 | ppl  1699.34
# | epoch   1 | seq number 67400 | lr 0.0003 | loss  9.06 | ppl  8607.17
# ...
# | epoch   6 | seq number 276900 | lr 0.0000 | loss  8.30 | ppl  4015.66
# | epoch   6 | seq number 277000 | lr 0.0000 | loss  7.53 | ppl  1868.92
# | epoch   6 | seq number 277100 | lr 0.0000 | loss  8.12 | ppl  3366.71
# | epoch   6 | seq number 277200 | lr 0.0000 | loss  7.78 | ppl  2392.42
# | epoch   6 | seq number 277300 | lr 0.0000 | loss  6.66 | ppl   776.77
# | epoch   6 | seq number 277400 | lr 0.0000 | loss  7.41 | ppl  1652.18
# | epoch   6 | seq number 277500 | lr 0.0000 | loss  7.92 | ppl  2763.68
# | epoch   6 | seq number 277600 | lr 0.0000 | loss  7.08 | ppl  1182.19
# | epoch   6 | seq number 277700 | lr 0.0000 | loss  8.02 | ppl  3042.85
# | epoch   6 | seq number 277800 | lr 0.0000 | loss  7.35 | ppl  1549.08
# | epoch   6 | seq number 277900 | lr 0.0000 | loss  7.57 | ppl  1931.79
# | epoch   6 | seq number 278000 | lr 0.0000 | loss  7.83 | ppl  2504.36
# | epoch   6 | seq number 278100 | lr 0.0000 | loss  6.50 | ppl   662.15
# | epoch   6 | seq number 278200 | lr 0.0000 | loss  7.90 | ppl  2704.83
# | epoch   6 | seq number 278300 | lr 0.0000 | loss  7.84 | ppl  2534.47
# | epoch   6 | seq number 278400 | lr 0.0000 | loss  8.10 | ppl  3293.34
# | epoch   6 | seq number 278500 | lr 0.0000 | loss  7.01 | ppl  1104.47
# | epoch   6 | seq number 278600 | lr 0.0000 | loss  8.52 | ppl  5005.04
# | epoch   6 | seq number 278700 | lr 0.0000 | loss  7.36 | ppl  1573.51
# | epoch   6 | seq number 278800 | lr 0.0000 | loss  7.94 | ppl  2808.92
# | epoch   6 | seq number 278900 | lr 0.0000 | loss  7.50 | ppl  1805.81
# | epoch   6 | seq number 279000 | lr 0.0000 | loss  7.31 | ppl  1501.69
# | epoch   6 | seq number 279100 | lr 0.0000 | loss  6.79 | ppl   887.99
# | epoch   6 | seq number 279200 | lr 0.0000 | loss  7.05 | ppl  1147.45
# | epoch   6 | seq number 279300 | lr 0.0000 | loss  8.21 | ppl  3682.31
# | epoch   6 | seq number 279400 | lr 0.0000 | loss  7.85 | ppl  2577.64
# | epoch   6 | seq number 279500 | lr 0.0000 | loss  7.05 | ppl  1152.90
# | epoch   6 | seq number 279600 | lr 0.0000 | loss  6.90 | ppl   988.07
# | epoch   6 | seq number 279700 | lr 0.0000 | loss  8.59 | ppl  5371.21
# | epoch   6 | seq number 279800 | lr 0.0000 | loss  4.73 | ppl   112.84
# | epoch   6 | seq number 279900 | lr 0.0000 | loss  6.62 | ppl   753.01
# | epoch   6 | seq number 280000 | lr 0.0000 | loss  7.05 | ppl  1157.58
# | epoch   6 | seq number 280100 | lr 0.0000 | loss  6.54 | ppl   695.49
# | epoch   6 | seq number 280200 | lr 0.0000 | loss  8.53 | ppl  5056.75
# | epoch   6 | seq number 280300 | lr 0.0000 | loss  8.21 | ppl  3685.08
# | epoch   6 | seq number 280400 | lr 0.0000 | loss  8.31 | ppl  4057.68
# | epoch   6 | seq number 280500 | lr 0.0000 | loss  6.98 | ppl  1070.28
# | epoch   6 | seq number 280600 | lr 0.0000 | loss  6.83 | ppl   921.59
# | epoch   6 | seq number 280700 | lr 0.0000 | loss  7.51 | ppl  1824.55
# | epoch   6 | seq number 280800 | lr 0.0000 | loss  7.44 | ppl  1695.25
# | epoch   6 | seq number 280900 | lr 0.0000 | loss  7.84 | ppl  2530.63
# | epoch   6 | seq number 281000 | lr 0.0000 | loss  7.70 | ppl  2208.61
# | epoch   6 | seq number 281100 | lr 0.0000 | loss  7.87 | ppl  2622.08
# | epoch   6 | seq number 281200 | lr 0.0000 | loss  8.55 | ppl  5156.13
# | epoch   6 | seq number 281300 | lr 0.0000 | loss  8.09 | ppl  3260.05
# | epoch   6 | seq number 281400 | lr 0.0000 | loss  8.22 | ppl  3726.97
# | epoch   6 | seq number 281500 | lr 0.0000 | loss  6.10 | ppl   444.42
# | epoch   6 | seq number 281600 | lr 0.0000 | loss  7.06 | ppl  1168.27
# | epoch   6 | seq number 281700 | lr 0.0000 | loss  7.11 | ppl  1221.11
# | epoch   6 | seq number 281800 | lr 0.0000 | loss  7.20 | ppl  1333.10
# | epoch   6 | seq number 281900 | lr 0.0000 | loss  7.34 | ppl  1542.07
# | epoch   6 | seq number 282000 | lr 0.0000 | loss  5.39 | ppl   218.85
# | epoch   6 | seq number 282100 | lr 0.0000 | loss  6.18 | ppl   484.28
# | epoch   6 | seq number 282200 | lr 0.0000 | loss  7.66 | ppl  2124.63
# | epoch   6 | seq number 282300 | lr 0.0000 | loss  7.88 | ppl  2635.70
# | epoch   6 | seq number 282400 | lr 0.0000 | loss  9.28 | ppl 10711.10
# | epoch   6 | seq number 282500 | lr 0.0000 | loss  7.89 | ppl  2677.60
# | epoch   6 | seq number 282600 | lr 0.0000 | loss  7.78 | ppl  2382.28
# | epoch   6 | seq number 282700 | lr 0.0000 | loss  6.78 | ppl   877.09
# | epoch   6 | seq number 282800 | lr 0.0000 | loss  6.83 | ppl   920.81
# | epoch   6 | seq number 282900 | lr 0.0000 | loss  9.43 | ppl 12493.37
# | epoch   6 | seq number 283000 | lr 0.0000 | loss  7.40 | ppl  1639.87
# | epoch   6 | seq number 283100 | lr 0.0000 | loss  8.29 | ppl  3977.22
# | epoch   6 | seq number 283200 | lr 0.0000 | loss  7.67 | ppl  2147.57
# | epoch   6 | seq number 283300 | lr 0.0000 | loss  6.89 | ppl   982.27
# | epoch   6 | seq number 283400 | lr 0.0000 | loss  7.48 | ppl  1776.83
# | epoch   6 | seq number 283500 | lr 0.0000 | loss  8.33 | ppl  4137.57
# | epoch   6 | seq number 283600 | lr 0.0000 | loss  7.90 | ppl  2685.22
# | epoch   6 | seq number 283700 | lr 0.0000 | loss  7.03 | ppl  1126.64
# | epoch   6 | seq number 283800 | lr 0.0000 | loss  9.19 | ppl  9803.21
# | epoch   6 | seq number 283900 | lr 0.0000 | loss  8.45 | ppl  4671.40
# | epoch   6 | seq number 284000 | lr 0.0000 | loss  7.62 | ppl  2030.95
# | epoch   6 | seq number 284100 | lr 0.0000 | loss  8.58 | ppl  5307.83
# | epoch   6 | seq number 284200 | lr 0.0000 | loss  7.10 | ppl  1210.82
# | epoch   6 | seq number 284300 | lr 0.0000 | loss  7.93 | ppl  2777.84
# | epoch   6 | seq number 284400 | lr 0.0000 | loss  7.26 | ppl  1420.59
# | epoch   6 | seq number 284500 | lr 0.0000 | loss  8.17 | ppl  3516.11
# | epoch   6 | seq number 284600 | lr 0.0000 | loss  7.01 | ppl  1104.78
# | epoch   6 | seq number 284700 | lr 0.0000 | loss  8.46 | ppl  4704.98
# | epoch   6 | seq number 284800 | lr 0.0000 | loss  7.62 | ppl  2037.41
# | epoch   6 | seq number 284900 | lr 0.0000 | loss  7.40 | ppl  1640.48
# | epoch   6 | seq number 285000 | lr 0.0000 | loss  7.11 | ppl  1229.27
# | epoch   6 | seq number 285100 | lr 0.0000 | loss  8.72 | ppl  6120.93
# | epoch   6 | seq number 285200 | lr 0.0000 | loss  7.77 | ppl  2359.19
# | epoch   6 | seq number 285300 | lr 0.0000 | loss  7.04 | ppl  1146.21
# | epoch   6 | seq number 285400 | lr 0.0000 | loss  8.59 | ppl  5364.43
# | epoch   6 | seq number 285500 | lr 0.0000 | loss  8.48 | ppl  4819.34
# | epoch   6 | seq number 285600 | lr 0.0000 | loss  7.67 | ppl  2141.90
# | epoch   6 | seq number 285700 | lr 0.0000 | loss  7.79 | ppl  2406.22
# | epoch   6 | seq number 285800 | lr 0.0000 | loss  7.03 | ppl  1130.93
# | epoch   6 | seq number 285900 | lr 0.0000 | loss  7.49 | ppl  1792.66
# | epoch   6 | seq number 286000 | lr 0.0000 | loss  7.13 | ppl  1252.03
# | epoch   6 | seq number 286100 | lr 0.0000 | loss  7.72 | ppl  2257.93
# | epoch   6 | seq number 286200 | lr 0.0000 | loss  6.53 | ppl   686.03
# | epoch   6 | seq number 286300 | lr 0.0000 | loss  6.67 | ppl   792.01
# | epoch   6 | seq number 286400 | lr 0.0000 | loss  5.64 | ppl   282.10
# | epoch   6 | seq number 286500 | lr 0.0000 | loss  7.01 | ppl  1102.33
# | epoch   6 | seq number 286600 | lr 0.0000 | loss  6.71 | ppl   821.51
# | epoch   6 | seq number 286700 | lr 0.0000 | loss  7.00 | ppl  1099.52
# | epoch   6 | seq number 286800 | lr 0.0000 | loss  7.42 | ppl  1660.99
# | epoch   6 | seq number 286900 | lr 0.0000 | loss  6.76 | ppl   865.44
# | epoch   6 | seq number 287000 | lr 0.0000 | loss  6.72 | ppl   830.09
# | epoch   6 | seq number 287100 | lr 0.0000 | loss  7.71 | ppl  2232.90
# | epoch   6 | seq number 287200 | lr 0.0000 | loss  7.66 | ppl  2111.63
# | epoch   6 | seq number 287300 | lr 0.0000 | loss  7.82 | ppl  2497.96
# | epoch   6 | seq number 287400 | lr 0.0000 | loss  7.63 | ppl  2066.83
# | epoch   6 | seq number 287500 | lr 0.0000 | loss  8.11 | ppl  3318.24
# | epoch   6 | seq number 287600 | lr 0.0000 | loss  7.40 | ppl  1634.78
# | epoch   6 | seq number 287700 | lr 0.0000 | loss  7.59 | ppl  1971.94
# | epoch   6 | seq number 287800 | lr 0.0000 | loss  7.44 | ppl  1696.24
# | epoch   6 | seq number 287900 | lr 0.0000 | loss  7.68 | ppl  2170.22
# | epoch   6 | seq number 288000 | lr 0.0000 | loss  8.01 | ppl  3024.68
# | epoch   6 | seq number 288100 | lr 0.0000 | loss  7.04 | ppl  1140.35
# | epoch   6 | seq number 288200 | lr 0.0000 | loss  9.02 | ppl  8307.28
# | epoch   6 | seq number 288300 | lr 0.0000 | loss  7.39 | ppl  1625.21
# | epoch   6 | seq number 288400 | lr 0.0000 | loss  8.70 | ppl  6012.83
# | epoch   6 | seq number 288500 | lr 0.0000 | loss  6.48 | ppl   655.08
# | epoch   6 | seq number 288600 | lr 0.0000 | loss  9.25 | ppl 10450.75
# | epoch   6 | seq number 288700 | lr 0.0000 | loss  6.14 | ppl   465.17
# | epoch   6 | seq number 288800 | lr 0.0000 | loss  8.08 | ppl  3227.54
# | epoch   6 | seq number 288900 | lr 0.0000 | loss  8.21 | ppl  3672.71
# | epoch   6 | seq number 289000 | lr 0.0000 | loss  7.69 | ppl  2192.33
# | epoch   6 | seq number 289100 | lr 0.0000 | loss  7.67 | ppl  2142.06
# | epoch   6 | seq number 289200 | lr 0.0000 | loss  8.16 | ppl  3494.73
# | epoch   6 | seq number 289300 | lr 0.0000 | loss  7.58 | ppl  1966.43
# | epoch   6 | seq number 289400 | lr 0.0000 | loss  7.91 | ppl  2711.88
# | epoch   6 | seq number 289500 | lr 0.0000 | loss  8.36 | ppl  4255.51
# | epoch   6 | seq number 289600 | lr 0.0000 | loss  6.83 | ppl   923.32
# | epoch   6 | seq number 289700 | lr 0.0000 | loss  6.52 | ppl   676.22
# | epoch   6 | seq number 289800 | lr 0.0000 | loss  7.96 | ppl  2855.00
# | epoch   6 | seq number 289900 | lr 0.0000 | loss  6.70 | ppl   815.39
# | epoch   6 | seq number 290000 | lr 0.0000 | loss  7.63 | ppl  2054.97
# | epoch   6 | seq number 290100 | lr 0.0000 | loss  6.28 | ppl   534.88
# | epoch   6 | seq number 290200 | lr 0.0000 | loss  8.24 | ppl  3770.95
# | epoch   6 | seq number 290300 | lr 0.0000 | loss  8.75 | ppl  6279.26
# | epoch   6 | seq number 290400 | lr 0.0000 | loss  7.95 | ppl  2849.62
# | epoch   6 | seq number 290500 | lr 0.0000 | loss  8.21 | ppl  3693.76
# | epoch   6 | seq number 290600 | lr 0.0000 | loss  6.82 | ppl   919.57
# | epoch   6 | seq number 290700 | lr 0.0000 | loss  8.73 | ppl  6164.23
# | epoch   6 | seq number 290800 | lr 0.0000 | loss  8.08 | ppl  3224.85
# | epoch   6 | seq number 290900 | lr 0.0000 | loss  8.33 | ppl  4144.93
# | epoch   6 | seq number 291000 | lr 0.0000 | loss  8.05 | ppl  3143.92
# | epoch   6 | seq number 291100 | lr 0.0000 | loss  6.82 | ppl   915.76
# | epoch   6 | seq number 291200 | lr 0.0000 | loss  6.86 | ppl   954.07
# | epoch   6 | seq number 291300 | lr 0.0000 | loss  7.27 | ppl  1442.57
# | epoch   6 | seq number 291400 | lr 0.0000 | loss  6.84 | ppl   934.06
# | epoch   6 | seq number 291500 | lr 0.0000 | loss  6.99 | ppl  1083.11
# | epoch   6 | seq number 291600 | lr 0.0000 | loss  8.05 | ppl  3126.90
# | epoch   6 | seq number 291700 | lr 0.0000 | loss  8.05 | ppl  3127.96
# | epoch   6 | seq number 291800 | lr 0.0000 | loss  8.51 | ppl  4964.83
# | epoch   6 | seq number 291900 | lr 0.0000 | loss  6.46 | ppl   640.83
# | epoch   6 | seq number 292000 | lr 0.0000 | loss  7.68 | ppl  2171.38
# | epoch   6 | seq number 292100 | lr 0.0000 | loss  8.45 | ppl  4660.81
# | epoch   6 | seq number 292200 | lr 0.0000 | loss  8.02 | ppl  3054.21
# | epoch   6 | seq number 292300 | lr 0.0000 | loss  8.06 | ppl  3172.46
# | epoch   6 | seq number 292400 | lr 0.0000 | loss  8.74 | ppl  6262.26
# | epoch   6 | seq number 292500 | lr 0.0000 | loss  6.63 | ppl   754.76
# | epoch   6 | seq number 292600 | lr 0.0000 | loss  6.42 | ppl   616.76
# | epoch   6 | seq number 292700 | lr 0.0000 | loss  8.71 | ppl  6063.23
# | epoch   6 | seq number 292800 | lr 0.0000 | loss  6.55 | ppl   700.57
# | epoch   6 | seq number 292900 | lr 0.0000 | loss  7.68 | ppl  2161.05
# | epoch   6 | seq number 293000 | lr 0.0000 | loss  7.78 | ppl  2383.82
# | epoch   6 | seq number 293100 | lr 0.0000 | loss  8.34 | ppl  4184.34
# | epoch   6 | seq number 293200 | lr 0.0000 | loss  8.39 | ppl  4399.15
# | epoch   6 | seq number 293300 | lr 0.0000 | loss  8.19 | ppl  3608.45
# | epoch   6 | seq number 293400 | lr 0.0000 | loss  8.70 | ppl  5983.39
# | epoch   6 | seq number 293500 | lr 0.0000 | loss  7.59 | ppl  1985.53
# | epoch   6 | seq number 293600 | lr 0.0000 | loss  9.61 | ppl 14920.38
# | epoch   6 | seq number 293700 | lr 0.0000 | loss  8.18 | ppl  3582.76
# | epoch   6 | seq number 293800 | lr 0.0000 | loss  9.04 | ppl  8467.41
# | epoch   6 | seq number 293900 | lr 0.0000 | loss  9.78 | ppl 17609.09
# | epoch   6 | seq number 294000 | lr 0.0000 | loss  8.88 | ppl  7171.12
# | epoch   6 | seq number 294100 | lr 0.0000 | loss  7.59 | ppl  1975.23
# | epoch   6 | seq number 294200 | lr 0.0000 | loss  8.53 | ppl  5044.82
# | epoch   6 | seq number 294300 | lr 0.0000 | loss  8.43 | ppl  4584.52
# | epoch   6 | seq number 294400 | lr 0.0000 | loss  7.53 | ppl  1857.40
# | epoch   6 | seq number 294500 | lr 0.0000 | loss  8.43 | ppl  4599.03
# | epoch   6 | seq number 294600 | lr 0.0000 | loss  7.98 | ppl  2916.01
# | epoch   6 | seq number 294700 | lr 0.0000 | loss  7.34 | ppl  1543.82
# | epoch   6 | seq number 294800 | lr 0.0000 | loss  7.52 | ppl  1853.23
# | epoch   6 | seq number 294900 | lr 0.0000 | loss  8.32 | ppl  4116.23
# | epoch   6 | seq number 295000 | lr 0.0000 | loss  7.02 | ppl  1121.85
# | epoch   6 | seq number 295100 | lr 0.0000 | loss  7.37 | ppl  1585.73
# | epoch   6 | seq number 295200 | lr 0.0000 | loss  7.65 | ppl  2092.11
# | epoch   6 | seq number 295300 | lr 0.0000 | loss  8.01 | ppl  3006.47
# | epoch   6 | seq number 295400 | lr 0.0000 | loss  8.02 | ppl  3052.84
# | epoch   6 | seq number 295500 | lr 0.0000 | loss  7.95 | ppl  2825.46
# | epoch   6 | seq number 295600 | lr 0.0000 | loss  6.33 | ppl   561.69
# | epoch   6 | seq number 295700 | lr 0.0000 | loss  6.76 | ppl   865.62
# | epoch   6 | seq number 295800 | lr 0.0000 | loss  7.48 | ppl  1766.70
# | epoch   6 | seq number 295900 | lr 0.0000 | loss  7.56 | ppl  1911.75
# | epoch   6 | seq number 296000 | lr 0.0000 | loss  7.82 | ppl  2485.94
# | epoch   6 | seq number 296100 | lr 0.0000 | loss  7.30 | ppl  1479.11
# | epoch   6 | seq number 296200 | lr 0.0000 | loss  7.95 | ppl  2831.14
# | epoch   6 | seq number 296300 | lr 0.0000 | loss  8.09 | ppl  3269.92
# | epoch   6 | seq number 296400 | lr 0.0000 | loss  8.57 | ppl  5268.60
# | epoch   6 | seq number 296500 | lr 0.0000 | loss  7.82 | ppl  2489.44
# | epoch   6 | seq number 296600 | lr 0.0000 | loss  7.43 | ppl  1678.56
# | epoch   6 | seq number 296700 | lr 0.0000 | loss  6.73 | ppl   833.13
# | epoch   6 | seq number 296800 | lr 0.0000 | loss  7.53 | ppl  1857.70
# | epoch   6 | seq number 296900 | lr 0.0000 | loss  8.69 | ppl  5913.57
# | epoch   6 | seq number 297000 | lr 0.0000 | loss  6.68 | ppl   793.22
# | epoch   6 | seq number 297100 | lr 0.0000 | loss  8.37 | ppl  4306.66
# | epoch   6 | seq number 297200 | lr 0.0000 | loss  6.05 | ppl   422.45
# | epoch   6 | seq number 297300 | lr 0.0000 | loss  6.94 | ppl  1030.06
# | epoch   6 | seq number 297400 | lr 0.0000 | loss  7.34 | ppl  1535.16
# | epoch   6 | seq number 297500 | lr 0.0000 | loss  6.40 | ppl   599.36
# | epoch   6 | seq number 297600 | lr 0.0000 | loss  8.30 | ppl  4034.38
# | epoch   6 | seq number 297700 | lr 0.0000 | loss  7.56 | ppl  1925.12
# | epoch   6 | seq number 297800 | lr 0.0000 | loss  7.44 | ppl  1709.40
# | epoch   6 | seq number 297900 | lr 0.0000 | loss  7.31 | ppl  1496.76
# | epoch   6 | seq number 298000 | lr 0.0000 | loss  7.46 | ppl  1743.46
# | epoch   6 | seq number 298100 | lr 0.0000 | loss  6.80 | ppl   893.78
# | epoch   6 | seq number 298200 | lr 0.0000 | loss  7.95 | ppl  2838.16
# | epoch   6 | seq number 298300 | lr 0.0000 | loss  6.43 | ppl   622.04
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 1657.59s | valid loss  8.75 | valid ppl  6341.36
# -----------------------------------------------------------------------------------------
# =========================================================================================
# | End of training | test loss  8.23 | test ppl  3743.54
# =========================================================================================
