# %%
# Q1_data
import os
from io import open
import torch

# Q1_model
import math
import torch.nn as nn
import torch.nn.functional as F

#Q1_main
# import argparse
import time
import torch.onnx
import numpy as np
from torch.autograd import Variable
import multiprocessing

# %% [code]
class Dictionary(object):
    def __init__(self):
        self.word2idx = {}
        self.idx2word = []

    def add_word(self, word):
        if word not in self.word2idx:
            self.idx2word.append(word)
            self.word2idx[word] = len(self.idx2word) - 1
        return self.word2idx[word]

    def __len__(self):
        return len(self.idx2word)


class Corpus(object):
    def __init__(self):
        self.dictionary = Dictionary()
        self.train = self.tokenize('../input/nlpdata/wikitext-2/wiki.train.tokens')
        self.valid = self.tokenize('../input/nlpdata/wikitext-2/wiki.valid.tokens')
        self.test = self.tokenize( '../input/nlpdata/wikitext-2/wiki.test.tokens')

    def tokenize(self, path):
        """Tokenizes a text file."""
       
        assert os.path.exists(path)
        # Add words to the dictionary
        with open(path, 'r', encoding="utf8") as f:
            for line in f:
                words = line.split() + ['<eos>']
                for word in words:
                    self.dictionary.add_word(word)

        # Tokenize file content
        with open(path, 'r', encoding="utf8") as f:
            idss = []
            for line in f:
                words = line.split() + ['<eos>']
                ids = []
                for word in words:
                    ids.append(self.dictionary.word2idx[word])
                idss.append(torch.tensor(ids).type(torch.int64))
            # print("idss",len(idss))
            ids = torch.cat(idss)
            # print("ids",len(ids))

        return ids


class RNNModel(nn.Module):
    """Container module with an encoder, a recurrent module, and a decoder."""

    def __init__(self, rnn_type, ntoken, ninp, nhid, nlayers, dropout=0.5, tie_weights=False):
        super(RNNModel, self).__init__()
        self.ntoken = ntoken # VOCAB SIZE
        self.drop = nn.Dropout(dropout)
        self.encoder = nn.Embedding(ntoken, ninp)
        if rnn_type in ['LSTM', 'GRU']:
            self.rnn = getattr(nn, rnn_type)(ninp, nhid, nlayers, dropout=dropout)
            # print(rnn_type)
        else:
            try:
                nonlinearity = {'RNN_TANH': 'tanh', 'RNN_RELU': 'relu'}[rnn_type]
            except KeyError:
                raise ValueError( """An invalid option for `--model` was supplied,
                                 options are ['LSTM', 'GRU', 'RNN_TANH' or 'RNN_RELU']""")
            self.rnn = nn.RNN(ninp, nhid, nlayers, nonlinearity=nonlinearity, dropout=dropout) # input size, hidden dimension, no of hidden layers size
        self.decoder = nn.Linear(nhid, ntoken) # hidden dimension, vocab size

        # Optionally tie weights as in:
        # "Using the Output Embedding to Improve Language Models" (Press & Wolf 2016)
        # https://arxiv.org/abs/1608.05859
        # and
        # "Tying Word Vectors and Word Classifiers: A Loss Framework for Language Modeling" (Inan et al. 2016)
        # https://arxiv.org/abs/1611.01462
        if tie_weights:
            if nhid != ninp:
                raise ValueError('When using the tied flag, nhid must be equal to emsize')
            self.decoder.weight = self.encoder.weight

        self.init_weights()

        self.rnn_type = rnn_type
        self.nhid = nhid
        self.nlayers = nlayers

    def init_weights(self):
        initrange = 0.1
        nn.init.uniform_(self.encoder.weight, -initrange, initrange)
        nn.init.zeros_(self.decoder.weight)
        nn.init.uniform_(self.decoder.weight, -initrange, initrange)

    def forward(self, input, hidden):
        emb = self.drop(self.encoder(input))
        output, hidden = self.rnn(emb, hidden)
        output = self.drop(output)
        decoded = self.decoder(output)
        decoded = decoded.view(-1, self.ntoken)
        return F.log_softmax(decoded, dim=1), hidden

    def init_hidden(self, bsz):
        weight = next(self.parameters())
        if self.rnn_type == 'LSTM':
            return (weight.new_zeros(self.nlayers, bsz, self.nhid),
                    weight.new_zeros(self.nlayers, bsz, self.nhid))
        else:
            return weight.new_zeros(self.nlayers, bsz, self.nhid)

# Temporarily leave PositionalEncoding module here. Will be moved somewhere else.
class PositionalEncoding(nn.Module):
    r"""Inject some information about the relative or absolute position of the tokens
        in the sequence. The positional encodings have the same dimension as
        the embeddings, so that the two can be summed. Here, we use sine and cosine
        functions of different frequencies.
    .. math::
        \text{PosEncoder}(pos, 2i) = sin(pos/10000^(2i/d_model))
        \text{PosEncoder}(pos, 2i+1) = cos(pos/10000^(2i/d_model))
        \text{where pos is the word position and i is the embed idx)
    Args:
        d_model: the embed dim (required).
        dropout: the dropout value (default=0.1).
        max_len: the max. length of the incoming sequence (default=5000).
    Examples:
        >>> pos_encoder = PositionalEncoding(d_model)
    """

    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        r"""Inputs of forward function
        Args:
            x: the sequence fed to the positional encoder model (required).
        Shape:
            x: [sequence length, batch size, embed dim]
            output: [sequence length, batch size, embed dim]
        Examples:
            >>> output = pos_encoder(x)
        """

        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

class TransformerModel(nn.Module):
    """Container module with an encoder, a recurrent or transformer module, and a decoder."""

    def _init_(self, ntoken, ninp, nhead, nhid, nlayers, dropout=0.5):
        super(TransformerModel, self)._init_()
        try:
            from torch.nn import TransformerEncoder, TransformerEncoderLayer
        except:
            raise ImportError('TransformerEncoder module does not exist in PyTorch 1.1 or lower.')
        self.model_type = 'Transformer'
        self.src_mask = None
        self.pos_encoder = PositionalEncoding(ninp, dropout)
        encoder_layers = TransformerEncoderLayer(ninp, nhead, nhid, dropout)
        self.transformer_encoder = TransformerEncoder(encoder_layers, nlayers)
        self.encoder = nn.Embedding(ntoken, ninp)
        self.ninp = ninp
        self.decoder = nn.Linear(ninp, ntoken)

        self.init_weights()

    def _generate_square_subsequent_mask(self, sz):
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask

    def init_weights(self):
        initrange = 0.1
        nn.init.uniform_(self.encoder.weight, -initrange, initrange)
        nn.init.zeros_(self.decoder.weight)
        nn.init.uniform_(self.decoder.weight, -initrange, initrange)

    def forward(self, src, has_mask=True):
        if has_mask:
            device = src.device
            if self.src_mask is None or self.src_mask.size(0) != len(src):
                mask = self._generate_square_subsequent_mask(len(src)).to(device)
                self.src_mask = mask
        else:
            self.src_mask = None

        src = self.encoder(src) * math.sqrt(self.ninp)
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src, self.src_mask)
        output = self.decoder(output)
        return F.log_softmax(output, dim=-1)



class FNNModel(nn.Module):

    def __init__(self, ntoken, ninp, nhid):
        super(FNNModel, self).__init__()

        self.embeddings = nn.Embedding(ntoken, ninp)
       
        self.linear = nn.Linear(7*ninp, nhid)
        self.linear2 = nn.Linear(nhid, ntoken)

        self.ntoken = ntoken
        self.init_weights()
        self.nhid = nhid

    def init_weights(self):
        initrange = 0.1
        nn.init.uniform_(self.embeddings.weight, -initrange, initrange)
        nn.init.zeros_(self.linear2.weight)
        nn.init.uniform_(self.linear2.weight, -initrange, initrange)

    def forward(self, input):
        embeds = self.embeddings(input)
        embeds = embeds.view(1,-1)
        out = F.tanh(self.linear(embeds))
        log_probs = F.log_softmax(self.linear2(out))
        return log_probs

class FNNModelSharing(nn.Module):

    def __init__(self, ntoken, ninp, nhid):
        super(FNNModelSharing, self).__init__()

        self.embeddings = nn.Embedding(ntoken, ninp)
       
        self.linear = nn.Linear(7*ninp, nhid)
        self.linear2 = nn.Linear(nhid, ntoken)
       
        self.linear2.weight.data = self.embeddings.weight.data

        self.ntoken = ntoken
        self.init_weights()
        self.nhid = nhid

    def init_weights(self):
        initrange = 0.1
        nn.init.uniform_(self.embeddings.weight, -initrange, initrange)
        nn.init.zeros_(self.linear2.weight)
        nn.init.uniform_(self.linear2.weight, -initrange, initrange)

    def forward(self, input):
        embeds = self.embeddings(input)
        embeds = embeds.view(1,-1)
        out = F.tanh(self.linear(embeds))
       
        out = self.linear2(out)
        log_probs = F.log_softmax(out, dim=1)
        return log_probs


data = 'wikitext-2'
model_name = 'FNN'
emsize = 200
nhid = 200
nlayers = 2
lr = 0.0003
clip = 0.25
epochs = 6
batch_size = 20
bptt = 8
dropout = 0.2
seed = 1111
tied = True
save = 'model_kag.pt'
onnx_export = ''
nhead = 2
dry_run = False
cuda_var = True
log_interval = 100

# Set the random seed manually for reproducibility.
torch.manual_seed(seed)
if torch.cuda.is_available():
    if not cuda_var:
        print("WARNING: You have a CUDA device, so you should probably run with --cuda")

device = torch.device("cuda" if cuda_var else "cpu")

###############################################################################
# Load data
###############################################################################

corpus = Corpus()
# print("final train",len(corpus.train))

# Starting from sequential data, batchify arranges the dataset into columns.
# For instance, with the alphabet as the sequence and batch size 4, we'd get
# ┌ a g m s ┐
# │ b h n t │
# │ c i o u │
# │ d j p v │
# │ e k q w │
# └ f l r x ┘.
# These columns are treated as independent by the model, which means that the
# dependence of e. g. 'g' on 'f' can not be learned, but allows more efficient
# batch processing.

def batchify(data, bsz):
    # Work out how cleanly we can divide the dataset into bsz parts.
    nbatch = data.size(0) // bsz
    # Trim off any extra elements that wouldn't cleanly fit (remainders).
    data = data.narrow(0, 0, nbatch * bsz)
    # Evenly divide the data across the bsz batches.
    data = data.view(bsz, -1).t().contiguous()
    print("data type ------ ", data.shape)
    return data.to(device)

# torch.Size([104431, 20])
ngram_here = torch.split(corpus.train, 7)
ngram_here = [t.numpy() for t in ngram_here]
ngram_here = ngram_here[:-1]
ngram_here = torch.tensor(ngram_here)
ngram_here = ngram_here.to(device)

val_data = torch.split(corpus.valid, 7)
val_data = [t.numpy() for t in val_data]
val_data = val_data[:-1]
val_data = torch.tensor(val_data)
val_data = val_data.to(device)

test_data = torch.split(corpus.test, 7)
test_data = [t.numpy() for t in test_data]
test_data = test_data[:-1]
test_data = torch.tensor(test_data)
test_data = test_data.to(device)
print("reached")

eval_batch_size = 10
if model_name  != 'FNN' and model_name != 'FNNS':
    train_data = batchify(corpus.train, batch_size)
    val_data = batchify(corpus.valid, eval_batch_size)
    test_data = batchify(corpus.test, eval_batch_size)
   


###############################################################################
# Build the model
###############################################################################

ntokens = len(corpus.dictionary)
if model_name  == 'Transformer':
    model = TransformerModel(ntokens, emsize, nhead, nhid, nlayers, dropout).to(device)
elif  model_name  == 'FNN':
    model = FNNModel(ntokens, emsize, nhid)
    optimizer = torch.optim.Adam(model.parameters(), lr = lr)
elif model_name  == 'FNNS':
    model = FNNModelSharing(ntokens, emsize, nhid)
    optimizer = torch.optim.Adam(model.parameters(), lr = lr)
    # optimizer = torch.optim.SGD(model.parameters(), lr, momentum=0.9)
else:
    model = RNNModel(model_name, ntokens, emsize, nhid, nlayers, dropout, tied).to(device)
 

criterion = nn.NLLLoss()

###############################################################################
# Training code
###############################################################################

def repackage_hidden(h):
    """Wraps hidden states in new Tensors, to detach them from their history."""

    if isinstance(h, torch.Tensor):
        return h.detach()
    else:
        return tuple(repackage_hidden(v) for v in h)


# get_batch subdivides the source data into chunks of length bptt.
# If source is equal to the example output of the batchify function, with
# a bptt-limit of 2, we'd get the following two Variables for i = 0:
# ┌ a g m s ┐ ┌ b h n t ┐
# └ b h n t ┘ └ c i o u ┘
# Note that despite the name of the function, the subdivison of data is not
# done along the batch dimension (i.e. dimension 1), since that was handled
# by the batchify function. The chunks are along dimension 0, corresponding
# to the seq_len dimension in the LSTM.

def get_batch(source, i):
    # print("i " ,i)
    seq_len = min(bptt, len(source) - 1 - i)
    # print("SEQLEN",seq_len)
    data = source[i:i+seq_len]
    # print("DATA SHAPE ",data.shape)
    target = source[i+1:i+1+seq_len].view(-1)
    return data, target


def evaluate(data_source):
    # Turn on evaluation mode which disables dropout.
    model.eval()
    total_loss = 0.
    ntokens = len(corpus.dictionary)
    if model_name  != 'Transformer' and model_name  != 'FNN' and model_name  != 'FNNS':
        hidden = model.init_hidden(eval_batch_size)
   
    with torch.no_grad():
        if model_name  != 'FNN' and model_name  != 'FNNS':
            for i in range(0, data_source.size(0) - 1, bptt):
                data, targets = get_batch(data_source, i)
                if model_name  == 'Transformer' or model_name  == 'FNN' or model_name  == 'FNNS':
                    output = model(data)
                    output = output.view(-1, ntokens)
                else:
                    output, hidden = model(data, hidden)
                    hidden = repackage_hidden(hidden)
                print("len of data", len(data))
                total_loss += len(data) * criterion(output, targets).item()
        else: #for FNN
            for i in range(len(data_source)-1):
                data = data_source[i]
                ngram_copy = list(data_source[i+1])
                targets = ngram_copy[0]
                targets = [targets]
                targets = torch.tensor(targets)
                targets = targets.to(device)
                #print("tar",targets)
                output = model(data)
                #print("op", output)
#                 print("critereonnnn",criterion(output, targets).item())
                total_loss +=  criterion(output, targets).item()
                
#                 if i % log_interval == 0 and i > 0:
#                     total_loss = 0
#     print("data source -- ",len(data_source))
    return total_loss / (len(data_source) - 1)



def train():
    # Turn on training mode which enables dropout.
    model.train()
    total_loss = 0.
    start_time = time.time()
    ntokens = len(corpus.dictionary)
    # print("--------", model)
    if model_name  != 'Transformer' and model_name  != 'FNN' and model_name  != 'FNNS':
        hidden = model.init_hidden(batch_size)
    if model_name  != 'FNN' and model_name  != 'FNNS':
        for batch, i in enumerate(range(0, int(train_data.size(0)/10000) - 1, bptt)):
            # print("batch issssss",batch)
            data, targets = get_batch(train_data, i)
#             print("data-------",data)
            print("target-----", targets)
            # Starting each batch, we detach the hidden state from how it was previously produced.
            # If we didn't, the model would try backpropagating all the way to start of the dataset.
            model.zero_grad()
            if model_name  == 'Transformer' or model_name  == 'FNN' or model_name == 'FNNS':
                optimizer.zero_grad()
                output = model(data)
                output = output.view(-1, ntokens)
                
            else:
                hidden = repackage_hidden(hidden)
                output, hidden = model(data, hidden)
                print("output---", output)
            loss = criterion(output, targets)
            loss.backward()
            # optimizer.step()


            # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
            # if model != 'Transformer' and model != 'FNN':
            torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
            for p in model.parameters():
                p.data.add_(p.grad, alpha=-lr)

            total_loss += loss.item()

            if batch % log_interval == 0 and batch > 0:
                cur_loss = total_loss / log_interval
                elapsed = time.time() - start_time
                print('| epoch {:3d} | {:5d}/{:5d} batches | lr {:02.4f} | ms/batch {:5.2f} | '
                        'loss {:5.2f} | ppl {:8.2f}'.format(
                    epoch, batch, len(train_data) // bptt, lr,
                    elapsed * 1000 / log_interval,
                    cur_loss,
                    np.exp(cur_loss)))
                total_loss = 0
                start_time = time.time()
            if dry_run:
                break
               
    else: #for FNN
        # print("here")
        count = 0
        for i in range(int(len(ngram_here))-1):
            data = ngram_here[i]
            ngram_copy = list(ngram_here[i+1])
            targets = ngram_copy[0]
            targets = [targets]
            targets = torch.tensor(targets)
            targets = targets.to(device)
            # print("data", data)
            # print("target", targets)
           
            model.zero_grad()
            model.to(device)
            optimizer.zero_grad()
            output = model(data)
            # print("op", output)
            loss = criterion(output, targets)
            loss.backward()
            optimizer.step()

            torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
            for p in model.parameters():
                p.data.add_(p.grad, alpha=-lr)

            total_loss += loss.item()

            if count % log_interval == 0 and count > 0:
                cur_loss = total_loss / log_interval
                elapsed = time.time() - start_time
                print('| epoch {:3d} | seq number {:3d} | lr {:02.4f} | '
                        'loss {:5.2f} | ppl {:8.2f}'.format(
                    epoch, count, lr,
                    cur_loss,
                    np.exp(cur_loss)))
                total_loss = 0
                start_time = time.time()

            count+=1



def export_onnx(path, batch_size, seq_len):
    print('The model is also exported in ONNX format at {}'.
          format(os.path.realpath(onnx_export)))
    model.eval()
    dummy_input = torch.LongTensor(seq_len * batch_size).zero_().view(-1, batch_size).to(device)
   
    hidden = model.init_hidden(batch_size)
    torch.onnx.export(model, (dummy_input, hidden), path)
    
    

# Loop over epochs.
lr = lr
best_val_loss = None

# At any point you can hit Ctrl + C to break out of training early.
try:
    for epoch in range(1, epochs+1):
        epoch_start_time = time.time()
        train()
        val_loss = evaluate(val_data)
        print('-' * 89)
        print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
                'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                           val_loss, np.exp(val_loss))) #math
        print('-' * 89)
        
        # Save the model if the validation loss is the best we've seen so far.
        if not best_val_loss or val_loss < best_val_loss:
            with open(save, 'wb') as f:
                torch.save(model, f)
            best_val_loss = val_loss
        else:
            # Anneal the learning rate if no improvement has been seen in the validation dataset.
            lr /= 4.0
except KeyboardInterrupt:
    print('-' * 89)
    print('Exiting from training early')

# Load the best saved model.
with open(save, 'rb') as f:
    model = torch.load(f)
    # after load the rnn params are not a continuous chunk of memory
    # Currently, only rnn model supports flatten_parameters function.
    if model_name  in ['RNN_TANH', 'RNN_RELU', 'LSTM', 'GRU']:
        model.rnn.flatten_parameters()

# Run on test data.
test_loss = evaluate(test_data)
print('=' * 89)
print('| End of training | test loss {:5.2f} | test ppl {:8.2f}'.format(
    test_loss, math.exp(test_loss)))
print('=' * 89)

if len(onnx_export) > 0:
    # Export the model in ONNX format.
    export_onnx(onnx_export, batch_size=1, seq_len=bptt)
# Out:
# reached
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1614: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:244: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# | epoch   1 | seq number 100 | lr 0.0003 | loss 10.50 | ppl 36272.98
# | epoch   1 | seq number 200 | lr 0.0003 | loss 10.36 | ppl 31461.10
# | epoch   1 | seq number 300 | lr 0.0003 | loss 10.19 | ppl 26756.01
# | epoch   1 | seq number 400 | lr 0.0003 | loss  9.86 | ppl 19120.44
# | epoch   1 | seq number 500 | lr 0.0003 | loss  8.21 | ppl  3662.59
# | epoch   1 | seq number 600 | lr 0.0003 | loss  8.12 | ppl  3356.87
# | epoch   1 | seq number 700 | lr 0.0003 | loss  8.44 | ppl  4622.47
# | epoch   1 | seq number 800 | lr 0.0003 | loss  7.69 | ppl  2185.40
# | epoch   1 | seq number 900 | lr 0.0003 | loss  8.04 | ppl  3115.38
# | epoch   1 | seq number 1000 | lr 0.0003 | loss  8.30 | ppl  4043.92
# | epoch   1 | seq number 1100 | lr 0.0003 | loss  7.91 | ppl  2712.94
# | epoch   1 | seq number 1200 | lr 0.0003 | loss  8.02 | ppl  3030.18
# | epoch   1 | seq number 1300 | lr 0.0003 | loss  7.30 | ppl  1476.33
# | epoch   1 | seq number 1400 | lr 0.0003 | loss  8.39 | ppl  4412.38
# | epoch   1 | seq number 1500 | lr 0.0003 | loss  8.28 | ppl  3944.83
# | epoch   1 | seq number 1600 | lr 0.0003 | loss  8.27 | ppl  3916.72
# | epoch   1 | seq number 1700 | lr 0.0003 | loss  7.98 | ppl  2920.08
# | epoch   1 | seq number 1800 | lr 0.0003 | loss  7.74 | ppl  2293.29
# | epoch   1 | seq number 1900 | lr 0.0003 | loss  8.22 | ppl  3706.90
# | epoch   1 | seq number 2000 | lr 0.0003 | loss  7.44 | ppl  1699.57
# | epoch   1 | seq number 2100 | lr 0.0003 | loss  7.78 | ppl  2385.87
# | epoch   1 | seq number 2200 | lr 0.0003 | loss  8.55 | ppl  5171.64
# | epoch   1 | seq number 2300 | lr 0.0003 | loss  8.74 | ppl  6266.80
# | epoch   1 | seq number 2400 | lr 0.0003 | loss  7.55 | ppl  1893.74
# | epoch   1 | seq number 2500 | lr 0.0003 | loss  7.68 | ppl  2169.18
# | epoch   1 | seq number 2600 | lr 0.0003 | loss  7.73 | ppl  2275.01
# | epoch   1 | seq number 2700 | lr 0.0003 | loss  7.16 | ppl  1285.96
# | epoch   1 | seq number 2800 | lr 0.0003 | loss  7.31 | ppl  1501.80
# | epoch   1 | seq number 2900 | lr 0.0003 | loss  7.59 | ppl  1971.15
# | epoch   1 | seq number 3000 | lr 0.0003 | loss  7.59 | ppl  1978.33
# | epoch   1 | seq number 3100 | lr 0.0003 | loss  8.09 | ppl  3274.55
# | epoch   1 | seq number 3200 | lr 0.0003 | loss  8.25 | ppl  3809.72
# | epoch   1 | seq number 3300 | lr 0.0003 | loss  8.61 | ppl  5505.49
# | epoch   1 | seq number 3400 | lr 0.0003 | loss  7.96 | ppl  2870.08
# | epoch   1 | seq number 3500 | lr 0.0003 | loss  7.90 | ppl  2710.71
# | epoch   1 | seq number 3600 | lr 0.0003 | loss  7.51 | ppl  1824.63
# | epoch   1 | seq number 3700 | lr 0.0003 | loss  8.03 | ppl  3057.92
# | epoch   1 | seq number 3800 | lr 0.0003 | loss  7.85 | ppl  2562.42
# | epoch   1 | seq number 3900 | lr 0.0003 | loss  7.19 | ppl  1321.22
# | epoch   1 | seq number 4000 | lr 0.0003 | loss  8.00 | ppl  2966.39
# | epoch   1 | seq number 4100 | lr 0.0003 | loss  7.88 | ppl  2640.25
# | epoch   1 | seq number 4200 | lr 0.0003 | loss  8.21 | ppl  3689.67
# | epoch   1 | seq number 4300 | lr 0.0003 | loss  8.15 | ppl  3461.28
# | epoch   1 | seq number 4400 | lr 0.0003 | loss  7.56 | ppl  1928.65
# | epoch   1 | seq number 4500 | lr 0.0003 | loss  8.25 | ppl  3842.51
# | epoch   1 | seq number 4600 | lr 0.0003 | loss  8.22 | ppl  3729.36
# | epoch   1 | seq number 4700 | lr 0.0003 | loss  8.13 | ppl  3406.56
# | epoch   1 | seq number 4800 | lr 0.0003 | loss  7.92 | ppl  2754.32
# | epoch   1 | seq number 4900 | lr 0.0003 | loss  7.95 | ppl  2830.83
# | epoch   1 | seq number 5000 | lr 0.0003 | loss  8.40 | ppl  4452.86
# | epoch   1 | seq number 5100 | lr 0.0003 | loss  7.96 | ppl  2877.46
# | epoch   1 | seq number 5200 | lr 0.0003 | loss  8.04 | ppl  3108.11
# | epoch   1 | seq number 5300 | lr 0.0003 | loss  7.78 | ppl  2382.50
# | epoch   1 | seq number 5400 | lr 0.0003 | loss  7.23 | ppl  1384.44
# | epoch   1 | seq number 5500 | lr 0.0003 | loss  7.11 | ppl  1228.23
# | epoch   1 | seq number 5600 | lr 0.0003 | loss  7.03 | ppl  1131.93
# | epoch   1 | seq number 5700 | lr 0.0003 | loss  7.05 | ppl  1151.71
# | epoch   1 | seq number 5800 | lr 0.0003 | loss  7.90 | ppl  2696.75
# | epoch   1 | seq number 5900 | lr 0.0003 | loss  8.06 | ppl  3167.26
# | epoch   1 | seq number 6000 | lr 0.0003 | loss  8.09 | ppl  3271.96
# | epoch   1 | seq number 6100 | lr 0.0003 | loss  7.65 | ppl  2097.44
# | epoch   1 | seq number 6200 | lr 0.0003 | loss  8.45 | ppl  4684.78
# | epoch   1 | seq number 6300 | lr 0.0003 | loss  7.91 | ppl  2734.30
# | epoch   1 | seq number 6400 | lr 0.0003 | loss  8.62 | ppl  5540.29
# | epoch   1 | seq number 6500 | lr 0.0003 | loss  8.03 | ppl  3057.13
# | epoch   1 | seq number 6600 | lr 0.0003 | loss  7.79 | ppl  2417.25
# | epoch   1 | seq number 6700 | lr 0.0003 | loss  8.12 | ppl  3350.12
# | epoch   1 | seq number 6800 | lr 0.0003 | loss  7.20 | ppl  1332.89
# | epoch   1 | seq number 6900 | lr 0.0003 | loss  8.01 | ppl  3017.63
# | epoch   1 | seq number 7000 | lr 0.0003 | loss  7.48 | ppl  1770.65
# | epoch   1 | seq number 7100 | lr 0.0003 | loss  8.19 | ppl  3606.76
# | epoch   1 | seq number 7200 | lr 0.0003 | loss  7.73 | ppl  2278.79
# | epoch   1 | seq number 7300 | lr 0.0003 | loss  6.99 | ppl  1080.78
# | epoch   1 | seq number 7400 | lr 0.0003 | loss  8.47 | ppl  4748.38
# | epoch   1 | seq number 7500 | lr 0.0003 | loss  7.44 | ppl  1702.35
# | epoch   1 | seq number 7600 | lr 0.0003 | loss  7.85 | ppl  2565.83
# | epoch   1 | seq number 7700 | lr 0.0003 | loss  7.34 | ppl  1533.98
# | epoch   1 | seq number 7800 | lr 0.0003 | loss  7.24 | ppl  1393.74
# | epoch   1 | seq number 7900 | lr 0.0003 | loss  8.19 | ppl  3621.03
# | epoch   1 | seq number 8000 | lr 0.0003 | loss  7.75 | ppl  2324.11
# | epoch   1 | seq number 8100 | lr 0.0003 | loss  7.60 | ppl  2005.80
# | epoch   1 | seq number 8200 | lr 0.0003 | loss  8.08 | ppl  3232.83
# | epoch   1 | seq number 8300 | lr 0.0003 | loss  7.51 | ppl  1828.53
# | epoch   1 | seq number 8400 | lr 0.0003 | loss  7.18 | ppl  1314.25
# | epoch   1 | seq number 8500 | lr 0.0003 | loss  6.94 | ppl  1030.00
# | epoch   1 | seq number 8600 | lr 0.0003 | loss  7.51 | ppl  1825.39
# | epoch   1 | seq number 8700 | lr 0.0003 | loss  7.18 | ppl  1317.40
# | epoch   1 | seq number 8800 | lr 0.0003 | loss  7.88 | ppl  2643.56
# | epoch   1 | seq number 8900 | lr 0.0003 | loss  7.69 | ppl  2189.21
# | epoch   1 | seq number 9000 | lr 0.0003 | loss  7.00 | ppl  1094.92
# | epoch   1 | seq number 9100 | lr 0.0003 | loss  8.16 | ppl  3497.52
# | epoch   1 | seq number 9200 | lr 0.0003 | loss  8.15 | ppl  3467.76
# | epoch   1 | seq number 9300 | lr 0.0003 | loss  7.68 | ppl  2172.66
# | epoch   1 | seq number 9400 | lr 0.0003 | loss  8.04 | ppl  3101.70
# | epoch   1 | seq number 9500 | lr 0.0003 | loss  7.73 | ppl  2267.92
# | epoch   1 | seq number 9600 | lr 0.0003 | loss  7.38 | ppl  1611.28
# | epoch   1 | seq number 9700 | lr 0.0003 | loss  7.48 | ppl  1763.60
# | epoch   1 | seq number 9800 | lr 0.0003 | loss  8.20 | ppl  3627.52
# | epoch   1 | seq number 9900 | lr 0.0003 | loss  7.51 | ppl  1828.65
# | epoch   1 | seq number 10000 | lr 0.0003 | loss  8.40 | ppl  4464.87
# | epoch   1 | seq number 10100 | lr 0.0003 | loss  7.59 | ppl  1984.44
# | epoch   1 | seq number 10200 | lr 0.0003 | loss  8.33 | ppl  4130.02
# | epoch   1 | seq number 10300 | lr 0.0003 | loss  7.50 | ppl  1806.23
# | epoch   1 | seq number 10400 | lr 0.0003 | loss  8.14 | ppl  3438.36
# | epoch   1 | seq number 10500 | lr 0.0003 | loss  7.92 | ppl  2748.44
# | epoch   1 | seq number 10600 | lr 0.0003 | loss  7.97 | ppl  2880.67
# | epoch   1 | seq number 10700 | lr 0.0003 | loss  7.29 | ppl  1460.62
# | epoch   1 | seq number 10800 | lr 0.0003 | loss  8.20 | ppl  3648.42
# | epoch   1 | seq number 10900 | lr 0.0003 | loss  8.01 | ppl  3020.31
# | epoch   1 | seq number 11000 | lr 0.0003 | loss  8.34 | ppl  4175.63
# | epoch   1 | seq number 11100 | lr 0.0003 | loss  7.11 | ppl  1223.24
# | epoch   1 | seq number 11200 | lr 0.0003 | loss  7.59 | ppl  1986.59
# | epoch   1 | seq number 11300 | lr 0.0003 | loss  7.74 | ppl  2296.35
# | epoch   1 | seq number 11400 | lr 0.0003 | loss  7.17 | ppl  1302.03
# | epoch   1 | seq number 11500 | lr 0.0003 | loss  6.72 | ppl   832.03
# | epoch   1 | seq number 11600 | lr 0.0003 | loss  7.29 | ppl  1468.71
# | epoch   1 | seq number 11700 | lr 0.0003 | loss  6.50 | ppl   667.00
# | epoch   1 | seq number 11800 | lr 0.0003 | loss  7.19 | ppl  1329.26
# | epoch   1 | seq number 11900 | lr 0.0003 | loss  7.11 | ppl  1224.75
# | epoch   1 | seq number 12000 | lr 0.0003 | loss  7.07 | ppl  1174.34
# | epoch   1 | seq number 12100 | lr 0.0003 | loss  6.81 | ppl   904.24
# | epoch   1 | seq number 12200 | lr 0.0003 | loss  7.45 | ppl  1715.39
# | epoch   1 | seq number 12300 | lr 0.0003 | loss  6.95 | ppl  1047.23
# | epoch   1 | seq number 12400 | lr 0.0003 | loss  8.04 | ppl  3116.73
# | epoch   1 | seq number 12500 | lr 0.0003 | loss  7.39 | ppl  1614.70
# | epoch   1 | seq number 12600 | lr 0.0003 | loss  8.48 | ppl  4815.38
# | epoch   1 | seq number 12700 | lr 0.0003 | loss  7.63 | ppl  2059.22
# | epoch   1 | seq number 12800 | lr 0.0003 | loss  6.63 | ppl   757.52
# | epoch   1 | seq number 12900 | lr 0.0003 | loss  8.29 | ppl  4001.08
# | epoch   1 | seq number 13000 | lr 0.0003 | loss  8.00 | ppl  2975.95
# | epoch   1 | seq number 13100 | lr 0.0003 | loss  6.75 | ppl   851.73
# | epoch   1 | seq number 13200 | lr 0.0003 | loss  8.02 | ppl  3050.78
# | epoch   1 | seq number 13300 | lr 0.0003 | loss  7.24 | ppl  1394.25
# | epoch   1 | seq number 13400 | lr 0.0003 | loss  7.94 | ppl  2802.89
# | epoch   1 | seq number 13500 | lr 0.0003 | loss  8.28 | ppl  3953.57
# | epoch   1 | seq number 13600 | lr 0.0003 | loss  8.40 | ppl  4449.18
# | epoch   1 | seq number 13700 | lr 0.0003 | loss  6.79 | ppl   887.27
# | epoch   1 | seq number 13800 | lr 0.0003 | loss  6.38 | ppl   590.06
# | epoch   1 | seq number 13900 | lr 0.0003 | loss  7.61 | ppl  2023.96
# | epoch   1 | seq number 14000 | lr 0.0003 | loss  6.54 | ppl   692.59
# | epoch   1 | seq number 14100 | lr 0.0003 | loss  7.90 | ppl  2687.84
# | epoch   1 | seq number 14200 | lr 0.0003 | loss  7.34 | ppl  1537.95
# | epoch   1 | seq number 14300 | lr 0.0003 | loss  7.78 | ppl  2380.63
# | epoch   1 | seq number 14400 | lr 0.0003 | loss  6.63 | ppl   754.82
# | epoch   1 | seq number 14500 | lr 0.0003 | loss  7.55 | ppl  1898.91
# | epoch   1 | seq number 14600 | lr 0.0003 | loss  7.82 | ppl  2480.51
# | epoch   1 | seq number 14700 | lr 0.0003 | loss  7.38 | ppl  1596.40
# | epoch   1 | seq number 14800 | lr 0.0003 | loss  7.36 | ppl  1571.95
# | epoch   1 | seq number 14900 | lr 0.0003 | loss  7.14 | ppl  1258.74
# | epoch   1 | seq number 15000 | lr 0.0003 | loss  7.68 | ppl  2156.35
# | epoch   1 | seq number 15100 | lr 0.0003 | loss  7.50 | ppl  1806.91
# | epoch   1 | seq number 15200 | lr 0.0003 | loss  7.49 | ppl  1782.42
# | epoch   1 | seq number 15300 | lr 0.0003 | loss  7.20 | ppl  1344.83
# | epoch   1 | seq number 15400 | lr 0.0003 | loss  7.68 | ppl  2173.05
# | epoch   1 | seq number 15500 | lr 0.0003 | loss  6.71 | ppl   822.25
# | epoch   1 | seq number 15600 | lr 0.0003 | loss  6.69 | ppl   803.14
# | epoch   1 | seq number 15700 | lr 0.0003 | loss  8.70 | ppl  6016.71
# | epoch   1 | seq number 15800 | lr 0.0003 | loss  7.93 | ppl  2772.18
# | epoch   1 | seq number 15900 | lr 0.0003 | loss  8.12 | ppl  3374.55
# | epoch   1 | seq number 16000 | lr 0.0003 | loss  7.59 | ppl  1987.81
# | epoch   1 | seq number 16100 | lr 0.0003 | loss  7.37 | ppl  1585.01
# | epoch   1 | seq number 16200 | lr 0.0003 | loss  7.73 | ppl  2275.11
# | epoch   1 | seq number 16300 | lr 0.0003 | loss  7.29 | ppl  1467.96
# | epoch   1 | seq number 16400 | lr 0.0003 | loss  7.88 | ppl  2644.77
# | epoch   1 | seq number 16500 | lr 0.0003 | loss  8.22 | ppl  3721.31
# | epoch   1 | seq number 27400 | lr 0.0003 | loss  7.08 | ppl  1189.21
# | epoch   1 | seq number 27500 | lr 0.0003 | loss  7.01 | ppl  1111.41
# | epoch   1 | seq number 27600 | lr 0.0003 | loss  7.64 | ppl  2070.91
# | epoch   1 | seq number 27700 | lr 0.0003 | loss  7.74 | ppl  2303.25
# | epoch   1 | seq number 27800 | lr 0.0003 | loss  6.23 | ppl   507.46
# | epoch   1 | seq number 27900 | lr 0.0003 | loss  7.67 | ppl  2133.88
# | epoch   1 | seq number 28000 | lr 0.0003 | loss  6.84 | ppl   937.46
# | epoch   1 | seq number 28100 | lr 0.0003 | loss  6.17 | ppl   478.04
# | epoch   1 | seq number 28200 | lr 0.0003 | loss  7.25 | ppl  1401.33
# | epoch   1 | seq number 28300 | lr 0.0003 | loss  7.15 | ppl  1279.45
# | epoch   1 | seq number 28400 | lr 0.0003 | loss  7.09 | ppl  1204.36
# | epoch   1 | seq number 28500 | lr 0.0003 | loss  7.04 | ppl  1139.65
# | epoch   1 | seq number 28600 | lr 0.0003 | loss  7.35 | ppl  1556.90
# | epoch   1 | seq number 28700 | lr 0.0003 | loss  7.33 | ppl  1523.40
# | epoch   1 | seq number 28800 | lr 0.0003 | loss  7.14 | ppl  1256.86
# | epoch   1 | seq number 28900 | lr 0.0003 | loss  8.28 | ppl  3933.41
# | epoch   1 | seq number 29000 | lr 0.0003 | loss  6.56 | ppl   708.40
# | epoch   1 | seq number 29100 | lr 0.0003 | loss  7.02 | ppl  1114.53
# | epoch   1 | seq number 29200 | lr 0.0003 | loss  7.12 | ppl  1231.95
# | epoch   1 | seq number 29300 | lr 0.0003 | loss  6.90 | ppl   990.96
# | epoch   1 | seq number 29400 | lr 0.0003 | loss  6.41 | ppl   610.60
# | epoch   1 | seq number 29500 | lr 0.0003 | loss  7.09 | ppl  1197.74
# | epoch   1 | seq number 29600 | lr 0.0003 | loss  7.22 | ppl  1366.11
# | epoch   1 | seq number 29700 | lr 0.0003 | loss  7.15 | ppl  1277.97
# | epoch   1 | seq number 29800 | lr 0.0003 | loss  6.49 | ppl   659.15
# | epoch   1 | seq number 29900 | lr 0.0003 | loss  7.61 | ppl  2015.05
# | epoch   1 | seq number 30000 | lr 0.0003 | loss  6.59 | ppl   729.81
# | epoch   1 | seq number 30100 | lr 0.0003 | loss  7.62 | ppl  2032.89
# | epoch   1 | seq number 30200 | lr 0.0003 | loss  7.05 | ppl  1155.14
# | epoch   1 | seq number 30300 | lr 0.0003 | loss  6.66 | ppl   781.88
# | epoch   1 | seq number 30400 | lr 0.0003 | loss  6.55 | ppl   701.77
# | epoch   1 | seq number 30500 | lr 0.0003 | loss  8.21 | ppl  3683.49
# | epoch   1 | seq number 30600 | lr 0.0003 | loss  8.13 | ppl  3401.31
# | epoch   1 | seq number 30700 | lr 0.0003 | loss  7.74 | ppl  2302.04
# | epoch   1 | seq number 30800 | lr 0.0003 | loss  7.42 | ppl  1671.90
# | epoch   1 | seq number 30900 | lr 0.0003 | loss  7.44 | ppl  1698.73
# | epoch   1 | seq number 31000 | lr 0.0003 | loss  7.03 | ppl  1128.00
# | epoch   1 | seq number 31100 | lr 0.0003 | loss  7.23 | ppl  1375.41
# | epoch   1 | seq number 31200 | lr 0.0003 | loss  8.12 | ppl  3375.15
# | epoch   1 | seq number 31300 | lr 0.0003 | loss  7.41 | ppl  1645.75
# | epoch   1 | seq number 31400 | lr 0.0003 | loss  6.79 | ppl   886.85
# | epoch   1 | seq number 31500 | lr 0.0003 | loss  7.45 | ppl  1718.58
# | epoch   1 | seq number 31600 | lr 0.0003 | loss  6.72 | ppl   830.04
# | epoch   1 | seq number 31700 | lr 0.0003 | loss  7.00 | ppl  1093.02
# | epoch   1 | seq number 31800 | lr 0.0003 | loss  6.95 | ppl  1041.87
# | epoch   1 | seq number 31900 | lr 0.0003 | loss  7.25 | ppl  1414.96
# | epoch   1 | seq number 32000 | lr 0.0003 | loss  6.46 | ppl   636.57
# | epoch   1 | seq number 32100 | lr 0.0003 | loss  7.12 | ppl  1238.86
# | epoch   1 | seq number 32200 | lr 0.0003 | loss  7.62 | ppl  2047.92
# | epoch   1 | seq number 32300 | lr 0.0003 | loss  6.90 | ppl   987.94
# | epoch   1 | seq number 32400 | lr 0.0003 | loss  6.92 | ppl  1009.41
# | epoch   1 | seq number 32500 | lr 0.0003 | loss  7.27 | ppl  1432.46
# | epoch   1 | seq number 32600 | lr 0.0003 | loss  7.82 | ppl  2489.61
# | epoch   1 | seq number 32700 | lr 0.0003 | loss  7.18 | ppl  1311.87
# | epoch   1 | seq number 32800 | lr 0.0003 | loss  7.98 | ppl  2925.70
# | epoch   1 | seq number 32900 | lr 0.0003 | loss  7.41 | ppl  1646.96
# | epoch   1 | seq number 33000 | lr 0.0003 | loss  7.37 | ppl  1594.87
# | epoch   1 | seq number 33100 | lr 0.0003 | loss  7.98 | ppl  2927.14
# | epoch   1 | seq number 33200 | lr 0.0003 | loss  7.24 | ppl  1396.37
# | epoch   1 | seq number 33300 | lr 0.0003 | loss  7.47 | ppl  1758.44
# | epoch   1 | seq number 33400 | lr 0.0003 | loss  6.89 | ppl   985.88
# | epoch   1 | seq number 33500 | lr 0.0003 | loss  7.19 | ppl  1329.53
# | epoch   1 | seq number 33600 | lr 0.0003 | loss  7.20 | ppl  1341.27
# | epoch   1 | seq number 33700 | lr 0.0003 | loss  6.94 | ppl  1028.16
# | epoch   1 | seq number 33800 | lr 0.0003 | loss  7.01 | ppl  1109.09
# | epoch   1 | seq number 33900 | lr 0.0003 | loss  6.74 | ppl   844.09
# | epoch   1 | seq number 34000 | lr 0.0003 | loss  8.17 | ppl  3548.18
# | epoch   1 | seq number 34100 | lr 0.0003 | loss  7.76 | ppl  2346.82
# | epoch   1 | seq number 34200 | lr 0.0003 | loss  7.11 | ppl  1223.41
# | epoch   1 | seq number 34300 | lr 0.0003 | loss  7.47 | ppl  1750.42
# | epoch   1 | seq number 34400 | lr 0.0003 | loss  6.90 | ppl   994.55
# | epoch   1 | seq number 34500 | lr 0.0003 | loss  7.88 | ppl  2648.96
# | epoch   1 | seq number 34600 | lr 0.0003 | loss  7.39 | ppl  1616.58
# | epoch   1 | seq number 38300 | lr 0.0003 | loss  6.72 | ppl   832.50
# | epoch   1 | seq number 38400 | lr 0.0003 | loss  7.60 | ppl  1988.76
# | epoch   1 | seq number 38500 | lr 0.0003 | loss  6.93 | ppl  1017.72
# | epoch   1 | seq number 38600 | lr 0.0003 | loss  6.95 | ppl  1048.30
# | epoch   1 | seq number 38700 | lr 0.0003 | loss  7.33 | ppl  1522.59
# | epoch   1 | seq number 38800 | lr 0.0003 | loss  7.08 | ppl  1191.55
# | epoch   1 | seq number 38900 | lr 0.0003 | loss  7.54 | ppl  1881.09
# | epoch   1 | seq number 39000 | lr 0.0003 | loss  7.00 | ppl  1095.43
# | epoch   1 | seq number 39100 | lr 0.0003 | loss  6.54 | ppl   694.50
# | epoch   1 | seq number 39200 | lr 0.0003 | loss  7.21 | ppl  1349.05
# | epoch   1 | seq number 39300 | lr 0.0003 | loss  6.84 | ppl   931.90
# | epoch   1 | seq number 39400 | lr 0.0003 | loss  7.41 | ppl  1651.72
# | epoch   1 | seq number 39500 | lr 0.0003 | loss  7.01 | ppl  1107.79
# | epoch   1 | seq number 39600 | lr 0.0003 | loss  6.89 | ppl   985.35
# | epoch   1 | seq number 39700 | lr 0.0003 | loss  6.98 | ppl  1079.48
# | epoch   1 | seq number 39800 | lr 0.0003 | loss  6.91 | ppl   998.14
# | epoch   1 | seq number 39900 | lr 0.0003 | loss  8.19 | ppl  3601.89
# | epoch   1 | seq number 40000 | lr 0.0003 | loss  7.60 | ppl  1999.68
# | epoch   1 | seq number 40100 | lr 0.0003 | loss  7.30 | ppl  1483.99
# | epoch   1 | seq number 40200 | lr 0.0003 | loss  7.68 | ppl  2163.52
# | epoch   1 | seq number 40300 | lr 0.0003 | loss  7.41 | ppl  1651.49
# | epoch   1 | seq number 40400 | lr 0.0003 | loss  7.60 | ppl  1992.18
# | epoch   1 | seq number 40500 | lr 0.0003 | loss  7.11 | ppl  1224.42
# | epoch   1 | seq number 40600 | lr 0.0003 | loss  7.21 | ppl  1349.46
# | epoch   1 | seq number 40700 | lr 0.0003 | loss  6.79 | ppl   890.71
# | epoch   1 | seq number 40800 | lr 0.0003 | loss  7.17 | ppl  1303.12
# | epoch   1 | seq number 40900 | lr 0.0003 | loss  7.09 | ppl  1200.31
# | epoch   1 | seq number 41000 | lr 0.0003 | loss  7.34 | ppl  1533.22
# | epoch   1 | seq number 41100 | lr 0.0003 | loss  7.18 | ppl  1306.95
# | epoch   1 | seq number 41200 | lr 0.0003 | loss  8.32 | ppl  4123.75
# | epoch   1 | seq number 41300 | lr 0.0003 | loss  7.23 | ppl  1374.28
# | epoch   1 | seq number 41400 | lr 0.0003 | loss  6.90 | ppl   988.74
# | epoch   1 | seq number 41500 | lr 0.0003 | loss  7.41 | ppl  1654.50
# | epoch   1 | seq number 41600 | lr 0.0003 | loss  7.44 | ppl  1701.06
# | epoch   1 | seq number 41700 | lr 0.0003 | loss  7.21 | ppl  1355.12
# | epoch   1 | seq number 41800 | lr 0.0003 | loss  8.04 | ppl  3101.87
# | epoch   1 | seq number 63600 | lr 0.0003 | loss  8.07 | ppl  3190.33
# | epoch   1 | seq number 63700 | lr 0.0003 | loss  8.13 | ppl  3386.39
# | epoch   1 | seq number 63800 | lr 0.0003 | loss  7.71 | ppl  2225.72
# | epoch   1 | seq number 63900 | lr 0.0003 | loss  6.65 | ppl   774.63
# | epoch   1 | seq number 64000 | lr 0.0003 | loss  7.39 | ppl  1619.29
# | epoch   1 | seq number 64100 | lr 0.0003 | loss  7.62 | ppl  2037.10
# | epoch   1 | seq number 64200 | lr 0.0003 | loss  7.50 | ppl  1801.76
# | epoch   1 | seq number 64300 | lr 0.0003 | loss  8.07 | ppl  3190.72
# | epoch   1 | seq number 64400 | lr 0.0003 | loss  8.48 | ppl  4797.89
# | epoch   1 | seq number 64500 | lr 0.0003 | loss  7.13 | ppl  1246.06
# | epoch   1 | seq number 64600 | lr 0.0003 | loss  7.71 | ppl  2221.94
# | epoch   1 | seq number 64700 | lr 0.0003 | loss  7.56 | ppl  1912.17
# | epoch   1 | seq number 64800 | lr 0.0003 | loss  7.74 | ppl  2304.57
# | epoch   1 | seq number 64900 | lr 0.0003 | loss  8.20 | ppl  3629.96
# | epoch   1 | seq number 65000 | lr 0.0003 | loss  8.12 | ppl  3350.99
# | epoch   1 | seq number 65100 | lr 0.0003 | loss  7.67 | ppl  2136.00
# | epoch   1 | seq number 65200 | lr 0.0003 | loss  8.33 | ppl  4134.96
# | epoch   1 | seq number 65300 | lr 0.0003 | loss  8.55 | ppl  5159.03
# | epoch   1 | seq number 65400 | lr 0.0003 | loss  8.01 | ppl  3017.88
# | epoch   1 | seq number 65500 | lr 0.0003 | loss  7.89 | ppl  2675.25
# | epoch   1 | seq number 65600 | lr 0.0003 | loss  8.03 | ppl  3078.24
# | epoch   1 | seq number 65700 | lr 0.0003 | loss  6.71 | ppl   820.62
# | epoch   1 | seq number 65800 | lr 0.0003 | loss  7.39 | ppl  1624.11
# | epoch   1 | seq number 65900 | lr 0.0003 | loss  7.25 | ppl  1412.18
# | epoch   1 | seq number 66000 | lr 0.0003 | loss  6.89 | ppl   986.23
# | epoch   1 | seq number 66100 | lr 0.0003 | loss  7.23 | ppl  1375.68
# | epoch   1 | seq number 66200 | lr 0.0003 | loss  8.23 | ppl  3753.54
# | epoch   1 | seq number 66300 | lr 0.0003 | loss  7.11 | ppl  1227.18
# | epoch   1 | seq number 66400 | lr 0.0003 | loss  8.32 | ppl  4124.88
# | epoch   1 | seq number 66500 | lr 0.0003 | loss  8.09 | ppl  3264.56
# | epoch   1 | seq number 66600 | lr 0.0003 | loss  7.80 | ppl  2449.47
# | epoch   1 | seq number 66700 | lr 0.0003 | loss  7.36 | ppl  1567.46
# | epoch   1 | seq number 66800 | lr 0.0003 | loss  7.81 | ppl  2464.78
# | epoch   1 | seq number 66900 | lr 0.0003 | loss  8.88 | ppl  7173.71
# | epoch   1 | seq number 67000 | lr 0.0003 | loss  8.12 | ppl  3371.86
# | epoch   1 | seq number 67100 | lr 0.0003 | loss  8.22 | ppl  3696.88
# ...
# | epoch   6 | seq number 276900 | lr 0.0000 | loss  8.38 | ppl  4341.25
# | epoch   6 | seq number 277000 | lr 0.0000 | loss  7.51 | ppl  1828.92
# | epoch   6 | seq number 277100 | lr 0.0000 | loss  8.09 | ppl  3264.84
# | epoch   6 | seq number 277200 | lr 0.0000 | loss  7.82 | ppl  2488.01
# | epoch   6 | seq number 277300 | lr 0.0000 | loss  6.58 | ppl   721.33
# | epoch   6 | seq number 277400 | lr 0.0000 | loss  7.46 | ppl  1730.43
# | epoch   6 | seq number 277500 | lr 0.0000 | loss  8.17 | ppl  3550.33
# | epoch   6 | seq number 277600 | lr 0.0000 | loss  7.11 | ppl  1228.52
# | epoch   6 | seq number 277700 | lr 0.0000 | loss  8.18 | ppl  3552.93
# | epoch   6 | seq number 277800 | lr 0.0000 | loss  7.78 | ppl  2396.92
# | epoch   6 | seq number 277900 | lr 0.0000 | loss  7.50 | ppl  1813.87
# | epoch   6 | seq number 278000 | lr 0.0000 | loss  7.78 | ppl  2388.01
# | epoch   6 | seq number 278100 | lr 0.0000 | loss  6.30 | ppl   544.47
# | epoch   6 | seq number 278200 | lr 0.0000 | loss  7.89 | ppl  2659.31
# | epoch   6 | seq number 278300 | lr 0.0000 | loss  7.99 | ppl  2952.83
# | epoch   6 | seq number 278400 | lr 0.0000 | loss  8.12 | ppl  3355.59
# | epoch   6 | seq number 278500 | lr 0.0000 | loss  7.06 | ppl  1170.00
# | epoch   6 | seq number 278600 | lr 0.0000 | loss  8.65 | ppl  5729.30
# | epoch   6 | seq number 278700 | lr 0.0000 | loss  7.42 | ppl  1663.34
# | epoch   6 | seq number 278800 | lr 0.0000 | loss  7.88 | ppl  2645.80
# | epoch   6 | seq number 278900 | lr 0.0000 | loss  7.54 | ppl  1890.72
# | epoch   6 | seq number 279000 | lr 0.0000 | loss  7.26 | ppl  1428.54
# | epoch   6 | seq number 279100 | lr 0.0000 | loss  6.74 | ppl   844.88
# | epoch   6 | seq number 279200 | lr 0.0000 | loss  7.00 | ppl  1097.98
# | epoch   6 | seq number 279300 | lr 0.0000 | loss  8.28 | ppl  3949.10
# | epoch   6 | seq number 279400 | lr 0.0000 | loss  7.69 | ppl  2194.04
# | epoch   6 | seq number 279500 | lr 0.0000 | loss  6.89 | ppl   986.89
# | epoch   6 | seq number 279600 | lr 0.0000 | loss  6.96 | ppl  1057.64
# | epoch   6 | seq number 279700 | lr 0.0000 | loss  8.57 | ppl  5246.28
# | epoch   6 | seq number 279800 | lr 0.0000 | loss  4.69 | ppl   108.98
# | epoch   6 | seq number 279900 | lr 0.0000 | loss  6.70 | ppl   813.06
# | epoch   6 | seq number 280000 | lr 0.0000 | loss  7.04 | ppl  1144.86
# | epoch   6 | seq number 280100 | lr 0.0000 | loss  6.49 | ppl   660.73
# | epoch   6 | seq number 280200 | lr 0.0000 | loss  8.65 | ppl  5714.88
# | epoch   6 | seq number 280300 | lr 0.0000 | loss  8.29 | ppl  3993.34
# | epoch   6 | seq number 280400 | lr 0.0000 | loss  8.40 | ppl  4427.11
# | epoch   6 | seq number 280500 | lr 0.0000 | loss  7.04 | ppl  1139.48
# | epoch   6 | seq number 280600 | lr 0.0000 | loss  6.72 | ppl   832.59
# | epoch   6 | seq number 280700 | lr 0.0000 | loss  7.45 | ppl  1718.38
# | epoch   6 | seq number 280800 | lr 0.0000 | loss  7.60 | ppl  1998.87
# | epoch   6 | seq number 280900 | lr 0.0000 | loss  7.87 | ppl  2618.32
# | epoch   6 | seq number 281000 | lr 0.0000 | loss  7.79 | ppl  2420.87
# | epoch   6 | seq number 281100 | lr 0.0000 | loss  8.02 | ppl  3031.23
# | epoch   6 | seq number 281200 | lr 0.0000 | loss  8.45 | ppl  4662.84
# | epoch   6 | seq number 281300 | lr 0.0000 | loss  8.04 | ppl  3093.96
# | epoch   6 | seq number 281400 | lr 0.0000 | loss  8.28 | ppl  3948.06
# | epoch   6 | seq number 281500 | lr 0.0000 | loss  6.11 | ppl   449.37
# | epoch   6 | seq number 281600 | lr 0.0000 | loss  7.03 | ppl  1130.03
# | epoch   6 | seq number 281700 | lr 0.0000 | loss  7.18 | ppl  1306.97
# | epoch   6 | seq number 281800 | lr 0.0000 | loss  7.32 | ppl  1505.56
# | epoch   6 | seq number 281900 | lr 0.0000 | loss  7.26 | ppl  1423.42
# | epoch   6 | seq number 282000 | lr 0.0000 | loss  5.61 | ppl   272.49
# | epoch   6 | seq number 282100 | lr 0.0000 | loss  6.21 | ppl   500.03
# | epoch   6 | seq number 282200 | lr 0.0000 | loss  7.47 | ppl  1758.85
# | epoch   6 | seq number 282300 | lr 0.0000 | loss  7.86 | ppl  2590.18
# | epoch   6 | seq number 282400 | lr 0.0000 | loss  9.30 | ppl 10903.93
# | epoch   6 | seq number 282500 | lr 0.0000 | loss  7.76 | ppl  2356.51
# | epoch   6 | seq number 282600 | lr 0.0000 | loss  7.79 | ppl  2422.31
# | epoch   6 | seq number 282700 | lr 0.0000 | loss  6.69 | ppl   805.20
# | epoch   6 | seq number 282800 | lr 0.0000 | loss  6.66 | ppl   782.34
# | epoch   6 | seq number 282900 | lr 0.0000 | loss  9.53 | ppl 13811.12
# | epoch   6 | seq number 283000 | lr 0.0000 | loss  7.33 | ppl  1530.69
# | epoch   6 | seq number 283100 | lr 0.0000 | loss  8.59 | ppl  5361.37
# | epoch   6 | seq number 283200 | lr 0.0000 | loss  7.72 | ppl  2244.84
# | epoch   6 | seq number 283300 | lr 0.0000 | loss  7.01 | ppl  1104.16
# | epoch   6 | seq number 283400 | lr 0.0000 | loss  7.34 | ppl  1541.39
# | epoch   6 | seq number 283500 | lr 0.0000 | loss  8.28 | ppl  3947.57
# | epoch   6 | seq number 283600 | lr 0.0000 | loss  7.96 | ppl  2851.54
# | epoch   6 | seq number 283700 | lr 0.0000 | loss  7.10 | ppl  1217.94
# | epoch   6 | seq number 283800 | lr 0.0000 | loss  9.17 | ppl  9645.53
# | epoch   6 | seq number 283900 | lr 0.0000 | loss  8.60 | ppl  5450.47
# | epoch   6 | seq number 284000 | lr 0.0000 | loss  7.50 | ppl  1808.11
# | epoch   6 | seq number 284100 | lr 0.0000 | loss  8.62 | ppl  5533.30
# | epoch   6 | seq number 284200 | lr 0.0000 | loss  7.18 | ppl  1314.55
# | epoch   6 | seq number 284300 | lr 0.0000 | loss  7.88 | ppl  2634.25
# | epoch   6 | seq number 284400 | lr 0.0000 | loss  7.38 | ppl  1606.94
# | epoch   6 | seq number 284500 | lr 0.0000 | loss  8.24 | ppl  3790.08
# | epoch   6 | seq number 284600 | lr 0.0000 | loss  7.14 | ppl  1259.06
# | epoch   6 | seq number 284700 | lr 0.0000 | loss  8.56 | ppl  5220.27
# | epoch   6 | seq number 284800 | lr 0.0000 | loss  7.69 | ppl  2188.61
# | epoch   6 | seq number 284900 | lr 0.0000 | loss  7.34 | ppl  1544.17
# | epoch   6 | seq number 285000 | lr 0.0000 | loss  7.08 | ppl  1184.32
# | epoch   6 | seq number 285100 | lr 0.0000 | loss  8.59 | ppl  5367.72
# | epoch   6 | seq number 285200 | lr 0.0000 | loss  7.65 | ppl  2095.89
# | epoch   6 | seq number 285300 | lr 0.0000 | loss  7.13 | ppl  1250.13
# | epoch   6 | seq number 285400 | lr 0.0000 | loss  8.47 | ppl  4778.97
# | epoch   6 | seq number 285500 | lr 0.0000 | loss  8.44 | ppl  4626.94
# | epoch   6 | seq number 285600 | lr 0.0000 | loss  7.76 | ppl  2340.45
# | epoch   6 | seq number 285700 | lr 0.0000 | loss  7.87 | ppl  2620.73
# | epoch   6 | seq number 285800 | lr 0.0000 | loss  7.12 | ppl  1238.15
# | epoch   6 | seq number 285900 | lr 0.0000 | loss  7.64 | ppl  2087.32
# | epoch   6 | seq number 286000 | lr 0.0000 | loss  7.29 | ppl  1462.51
# | epoch   6 | seq number 286100 | lr 0.0000 | loss  7.59 | ppl  1983.40
# | epoch   6 | seq number 286200 | lr 0.0000 | loss  6.51 | ppl   672.02
# | epoch   6 | seq number 286300 | lr 0.0000 | loss  6.64 | ppl   761.72
# | epoch   6 | seq number 286400 | lr 0.0000 | loss  5.67 | ppl   288.76
# | epoch   6 | seq number 286500 | lr 0.0000 | loss  6.86 | ppl   957.33
# | epoch   6 | seq number 286600 | lr 0.0000 | loss  6.51 | ppl   671.10
# | epoch   6 | seq number 286700 | lr 0.0000 | loss  6.85 | ppl   946.24
# | epoch   6 | seq number 286800 | lr 0.0000 | loss  7.68 | ppl  2157.85
# | epoch   6 | seq number 286900 | lr 0.0000 | loss  6.64 | ppl   764.00
# | epoch   6 | seq number 287000 | lr 0.0000 | loss  6.76 | ppl   865.30
# | epoch   6 | seq number 287100 | lr 0.0000 | loss  7.66 | ppl  2121.90
# | epoch   6 | seq number 287200 | lr 0.0000 | loss  7.73 | ppl  2276.49
# | epoch   6 | seq number 287300 | lr 0.0000 | loss  7.68 | ppl  2155.89
# | epoch   6 | seq number 287400 | lr 0.0000 | loss  7.79 | ppl  2414.44
# | epoch   6 | seq number 287500 | lr 0.0000 | loss  8.06 | ppl  3167.63
# | epoch   6 | seq number 287600 | lr 0.0000 | loss  7.47 | ppl  1761.66
# | epoch   6 | seq number 287700 | lr 0.0000 | loss  7.60 | ppl  2004.88
# | epoch   6 | seq number 287800 | lr 0.0000 | loss  7.39 | ppl  1618.26
# | epoch   6 | seq number 287900 | lr 0.0000 | loss  7.86 | ppl  2582.22
# | epoch   6 | seq number 288000 | lr 0.0000 | loss  8.10 | ppl  3310.20
# | epoch   6 | seq number 288100 | lr 0.0000 | loss  7.02 | ppl  1114.64
# | epoch   6 | seq number 288200 | lr 0.0000 | loss  9.15 | ppl  9374.55
# | epoch   6 | seq number 288300 | lr 0.0000 | loss  7.37 | ppl  1584.73
# | epoch   6 | seq number 288400 | lr 0.0000 | loss  8.85 | ppl  6996.51
# | epoch   6 | seq number 288500 | lr 0.0000 | loss  6.58 | ppl   721.30
# | epoch   6 | seq number 288600 | lr 0.0000 | loss  9.31 | ppl 11028.34
# | epoch   6 | seq number 288700 | lr 0.0000 | loss  6.09 | ppl   442.22
# | epoch   6 | seq number 288800 | lr 0.0000 | loss  8.07 | ppl  3206.81
# | epoch   6 | seq number 288900 | lr 0.0000 | loss  8.03 | ppl  3063.97
# | epoch   6 | seq number 289000 | lr 0.0000 | loss  7.64 | ppl  2083.61
# | epoch   6 | seq number 289100 | lr 0.0000 | loss  7.67 | ppl  2137.28
# | epoch   6 | seq number 289200 | lr 0.0000 | loss  8.27 | ppl  3915.12
# | epoch   6 | seq number 289300 | lr 0.0000 | loss  7.57 | ppl  1948.13
# | epoch   6 | seq number 289400 | lr 0.0000 | loss  7.90 | ppl  2691.27
# | epoch   6 | seq number 289500 | lr 0.0000 | loss  8.33 | ppl  4161.63
# | epoch   6 | seq number 289600 | lr 0.0000 | loss  6.84 | ppl   937.20
# | epoch   6 | seq number 289700 | lr 0.0000 | loss  6.51 | ppl   668.80
# | epoch   6 | seq number 289800 | lr 0.0000 | loss  7.99 | ppl  2942.60
# | epoch   6 | seq number 289900 | lr 0.0000 | loss  6.73 | ppl   833.83
# | epoch   6 | seq number 290000 | lr 0.0000 | loss  7.67 | ppl  2143.89
# | epoch   6 | seq number 290100 | lr 0.0000 | loss  6.25 | ppl   519.00
# | epoch   6 | seq number 290200 | lr 0.0000 | loss  8.33 | ppl  4145.78
# | epoch   6 | seq number 290300 | lr 0.0000 | loss  8.81 | ppl  6713.03
# | epoch   6 | seq number 290400 | lr 0.0000 | loss  8.14 | ppl  3415.53
# | epoch   6 | seq number 290500 | lr 0.0000 | loss  8.32 | ppl  4096.56
# | epoch   6 | seq number 290600 | lr 0.0000 | loss  6.69 | ppl   801.11
# | epoch   6 | seq number 290700 | lr 0.0000 | loss  8.62 | ppl  5547.34
# | epoch   6 | seq number 290800 | lr 0.0000 | loss  8.23 | ppl  3733.86
# | epoch   6 | seq number 290900 | lr 0.0000 | loss  8.39 | ppl  4402.03
# | epoch   6 | seq number 291000 | lr 0.0000 | loss  8.08 | ppl  3227.73
# | epoch   6 | seq number 291100 | lr 0.0000 | loss  7.00 | ppl  1100.96
# | epoch   6 | seq number 291200 | lr 0.0000 | loss  6.90 | ppl   995.45
# | epoch   6 | seq number 291300 | lr 0.0000 | loss  7.31 | ppl  1498.63
# | epoch   6 | seq number 291400 | lr 0.0000 | loss  6.79 | ppl   890.49
# | epoch   6 | seq number 291500 | lr 0.0000 | loss  7.12 | ppl  1239.63
# | epoch   6 | seq number 291600 | lr 0.0000 | loss  7.98 | ppl  2933.45
# | epoch   6 | seq number 291700 | lr 0.0000 | loss  8.07 | ppl  3201.59
# | epoch   6 | seq number 291800 | lr 0.0000 | loss  8.47 | ppl  4777.33
# | epoch   6 | seq number 291900 | lr 0.0000 | loss  6.63 | ppl   759.18
# | epoch   6 | seq number 292000 | lr 0.0000 | loss  7.75 | ppl  2331.22
# | epoch   6 | seq number 292100 | lr 0.0000 | loss  8.60 | ppl  5423.85
# | epoch   6 | seq number 292200 | lr 0.0000 | loss  8.00 | ppl  2986.50
# | epoch   6 | seq number 292300 | lr 0.0000 | loss  7.95 | ppl  2824.96
# | epoch   6 | seq number 292400 | lr 0.0000 | loss  8.45 | ppl  4681.91
# | epoch   6 | seq number 292500 | lr 0.0000 | loss  6.63 | ppl   753.80
# | epoch   6 | seq number 292600 | lr 0.0000 | loss  6.48 | ppl   648.85
# | epoch   6 | seq number 292700 | lr 0.0000 | loss  8.65 | ppl  5711.44
# | epoch   6 | seq number 292800 | lr 0.0000 | loss  6.58 | ppl   720.24
# | epoch   6 | seq number 292900 | lr 0.0000 | loss  7.65 | ppl  2108.77
# | epoch   6 | seq number 293000 | lr 0.0000 | loss  7.91 | ppl  2728.31
# | epoch   6 | seq number 293100 | lr 0.0000 | loss  8.22 | ppl  3713.11
# | epoch   6 | seq number 293200 | lr 0.0000 | loss  8.44 | ppl  4610.43
# | epoch   6 | seq number 293300 | lr 0.0000 | loss  8.08 | ppl  3220.66
# | epoch   6 | seq number 293400 | lr 0.0000 | loss  8.75 | ppl  6336.27
# | epoch   6 | seq number 293500 | lr 0.0000 | loss  7.49 | ppl  1796.33
# | epoch   6 | seq number 293600 | lr 0.0000 | loss  9.55 | ppl 14077.59
# | epoch   6 | seq number 293700 | lr 0.0000 | loss  8.11 | ppl  3311.25
# | epoch   6 | seq number 293800 | lr 0.0000 | loss  9.02 | ppl  8227.77
# | epoch   6 | seq number 293900 | lr 0.0000 | loss  9.66 | ppl 15729.10
# | epoch   6 | seq number 294000 | lr 0.0000 | loss  8.83 | ppl  6808.46
# | epoch   6 | seq number 294100 | lr 0.0000 | loss  7.73 | ppl  2275.65
# | epoch   6 | seq number 294200 | lr 0.0000 | loss  8.55 | ppl  5151.57
# | epoch   6 | seq number 294300 | lr 0.0000 | loss  8.38 | ppl  4349.49
# | epoch   6 | seq number 294400 | lr 0.0000 | loss  7.60 | ppl  2005.95
# | epoch   6 | seq number 294500 | lr 0.0000 | loss  8.56 | ppl  5193.27
# | epoch   6 | seq number 294600 | lr 0.0000 | loss  7.96 | ppl  2867.71
# | epoch   6 | seq number 294700 | lr 0.0000 | loss  7.32 | ppl  1511.78
# | epoch   6 | seq number 294800 | lr 0.0000 | loss  7.48 | ppl  1771.42
# | epoch   6 | seq number 294900 | lr 0.0000 | loss  8.21 | ppl  3673.63
# | epoch   6 | seq number 295000 | lr 0.0000 | loss  7.03 | ppl  1127.86
# | epoch   6 | seq number 295100 | lr 0.0000 | loss  7.29 | ppl  1472.25
# | epoch   6 | seq number 295200 | lr 0.0000 | loss  7.51 | ppl  1833.96
# | epoch   6 | seq number 295300 | lr 0.0000 | loss  8.05 | ppl  3130.27
# | epoch   6 | seq number 295400 | lr 0.0000 | loss  8.05 | ppl  3122.18
# | epoch   6 | seq number 295500 | lr 0.0000 | loss  7.92 | ppl  2757.87
# | epoch   6 | seq number 295600 | lr 0.0000 | loss  6.37 | ppl   585.18
# | epoch   6 | seq number 295700 | lr 0.0000 | loss  6.70 | ppl   809.41
# | epoch   6 | seq number 295800 | lr 0.0000 | loss  7.32 | ppl  1511.58
# | epoch   6 | seq number 295900 | lr 0.0000 | loss  7.54 | ppl  1883.31
# | epoch   6 | seq number 296000 | lr 0.0000 | loss  7.81 | ppl  2468.05
# | epoch   6 | seq number 296100 | lr 0.0000 | loss  7.40 | ppl  1629.90
# | epoch   6 | seq number 296200 | lr 0.0000 | loss  7.89 | ppl  2659.68
# | epoch   6 | seq number 296300 | lr 0.0000 | loss  8.04 | ppl  3092.09
# | epoch   6 | seq number 296400 | lr 0.0000 | loss  8.66 | ppl  5787.65
# | epoch   6 | seq number 296500 | lr 0.0000 | loss  7.69 | ppl  2192.10
# | epoch   6 | seq number 296600 | lr 0.0000 | loss  7.33 | ppl  1521.70
# | epoch   6 | seq number 296700 | lr 0.0000 | loss  6.78 | ppl   878.66
# | epoch   6 | seq number 296800 | lr 0.0000 | loss  7.56 | ppl  1928.64
# | epoch   6 | seq number 296900 | lr 0.0000 | loss  8.79 | ppl  6592.25
# | epoch   6 | seq number 297000 | lr 0.0000 | loss  6.83 | ppl   920.67
# | epoch   6 | seq number 297100 | lr 0.0000 | loss  8.45 | ppl  4668.48
# | epoch   6 | seq number 297200 | lr 0.0000 | loss  6.05 | ppl   425.73
# | epoch   6 | seq number 297300 | lr 0.0000 | loss  6.88 | ppl   976.79
# | epoch   6 | seq number 297400 | lr 0.0000 | loss  7.26 | ppl  1422.81
# | epoch   6 | seq number 297500 | lr 0.0000 | loss  6.36 | ppl   578.01
# | epoch   6 | seq number 297600 | lr 0.0000 | loss  8.27 | ppl  3905.37
# | epoch   6 | seq number 297700 | lr 0.0000 | loss  7.50 | ppl  1809.99
# | epoch   6 | seq number 297800 | lr 0.0000 | loss  7.36 | ppl  1568.22
# | epoch   6 | seq number 297900 | lr 0.0000 | loss  7.29 | ppl  1469.37
# | epoch   6 | seq number 298000 | lr 0.0000 | loss  7.44 | ppl  1695.69
# | epoch   6 | seq number 298100 | lr 0.0000 | loss  6.65 | ppl   776.58
# | epoch   6 | seq number 298200 | lr 0.0000 | loss  7.90 | ppl  2696.63
# | epoch   6 | seq number 298300 | lr 0.0000 | loss  6.56 | ppl   705.80
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 1326.54s | valid loss  8.78 | valid ppl  6502.92
# -----------------------------------------------------------------------------------------
# =========================================================================================
# | End of training | test loss  8.22 | test ppl  3696.64
# =========================================================================================
